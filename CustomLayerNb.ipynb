# %%
import sys
sys.path.insert(1,"/home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages") #work around for h5py
from cbrain.imports import *
from cbrain.cam_constants import *
from cbrain.utils import *
from cbrain.layers import *
from cbrain.data_generator import DataGenerator
import tensorflow as tf
import tensorflow.math as tfm
# import tensorflow_probability as tfp
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
import xarray as xr
import numpy as np
from cbrain.model_diagnostics import ModelDiagnostics
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.image as imag
import scipy.integrate as sin
# import cartopy.crs as ccrs
import matplotlib.ticker as mticker
# from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import pickle
# Out:
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
cd ../../
# Out:
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM

# %% [markdown]
# ## Pre-process data for the experiment

# %% [markdown]
# ### Specific humidity, norm file for (-4K)

# %%
# !python preprocessing-11132019.py -c /home1/07064/tg863631/CBrain_project/PrepData/CI_SP_M4K_NORM.yml
# Out:
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 02/06/2020 01:58:30 PM Preprocess training dataset
# 02/06/2020 01:58:30 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_SP_M4K_NORM_train.nc
# 02/06/2020 01:58:30 PM Reading input files
# 02/06/2020 01:58:30 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_minus4k/sp8fbp_minus4k.cam2.h2.0001-01-0*-00000.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/preprocessing/convert_dataset_20191113.py:404: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds = xr.open_mfdataset(in_fns, decode_times=False, decode_cf=False, concat_dim='time')
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 02/06/2020 01:58:52 PM Crop levels
# 02/06/2020 01:58:52 PM Create stacked dataarray
# var is  FLNS
# These time steps are cut: []
# 02/06/2020 01:58:52 PM Stack and reshape dataarray
# 02/06/2020 01:58:53 PM Save dataarray as /scratch/07064/tg863631/PrepData/CI_SP_M4K_NORM_train.nc
# 02/06/2020 01:59:02 PM Done!
# 02/06/2020 01:59:02 PM Shuffle training dataset
# 02/06/2020 01:59:02 PM Start shuffling /scratch/07064/tg863631/PrepData/CI_SP_M4K_NORM_train.nc into /scratch/07064/tg863631/PrepData/CI_SP_M4K_NORM_train_shuffle.nc. Open and create datasets.
# 02/06/2020 01:59:02 PM Shuffle!
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.05it/s]
# 02/06/2020 01:59:03 PM Closing datasets
# 02/06/2020 01:59:03 PM Done!
# 02/06/2020 01:59:03 PM Preprocess validation dataset
# 02/06/2020 01:59:03 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_SP_M4K_NORM_valid.nc
# 02/06/2020 01:59:03 PM Reading input files
# 02/06/2020 01:59:03 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_minus4k/sp8fbp_minus4k.cam2.h2.0001-01-0*-00000.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/preprocessing/convert_dataset_20191113.py:404: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds = xr.open_mfdataset(in_fns, decode_times=False, decode_cf=False, concat_dim='time')
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 02/06/2020 01:59:06 PM Crop levels
# 02/06/2020 01:59:06 PM Create stacked dataarray
# var is  FLNS
# These time steps are cut: []
# 02/06/2020 01:59:07 PM Stack and reshape dataarray
# 02/06/2020 01:59:07 PM Save dataarray as /scratch/07064/tg863631/PrepData/CI_SP_M4K_NORM_valid.nc
# 02/06/2020 01:59:08 PM Done!
# 02/06/2020 01:59:08 PM Compute normalization file from train
# 02/06/2020 01:59:08 PM Start normalizing by creating dataset.
# 02/06/2020 01:59:08 PM Compute standard normalizations.
# 02/06/2020 01:59:09 PM Saving normalization file as /scratch/07064/tg863631/PrepData/CI_SP_M4K_NORM_norm.nc
# 02/06/2020 01:59:09 PM Done!
# 02/06/2020 01:59:09 PM Finish entire preprocessing script.

# %% [markdown]
# ### Specific humidity, training and validation for (-4K)

# %%
# !python preprocessing-11132019.py -c /home1/07064/tg863631/CBrain_project/PrepData/CI_SP_M4K.yml
# Out:
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 02/04/2020 08:27:04 PM Preprocess training dataset
# 02/04/2020 08:27:04 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_SP_M4K_train.nc
# 02/04/2020 08:27:04 PM Reading input files
# 02/04/2020 08:27:04 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_minus4k/sp8fbp_minus4k.cam2.h2.0001-*-0*-00000.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/preprocessing/convert_dataset_20191113.py:404: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds = xr.open_mfdataset(in_fns, decode_times=False, decode_cf=False, concat_dim='time')
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 02/04/2020 08:31:27 PM Crop levels
# 02/04/2020 08:31:27 PM Create stacked dataarray
# var is  QBP
# var is  TBP
# var is  PS
# var is  SOLIN
# var is  SHFLX
# var is  LHFLX
# var is  PHQ
# var is  TPHYSTND
# var is  FSNT
# var is  FSNS
# var is  FLNT
# var is  FLNS
# These time steps are cut: [ 431  863 1295 1727 2159 2591 3023 3455 3887 4319 4751]
# 02/04/2020 08:31:28 PM Stack and reshape dataarray
# 02/04/2020 08:31:32 PM Save dataarray as /scratch/07064/tg863631/PrepData/CI_SP_M4K_train.nc
# 02/04/2020 09:37:56 PM Done!
# 02/04/2020 09:37:57 PM Shuffle training dataset
# 02/04/2020 09:37:57 PM Start shuffling /scratch/07064/tg863631/PrepData/CI_SP_M4K_train.nc into /scratch/07064/tg863631/PrepData/CI_SP_M4K_train_shuffle.nc. Open and create datasets.
# 02/04/2020 09:38:05 PM Shuffle!
# 100%|█████████████████████████████████████████████| 5/5 [05:26<00:00, 65.30s/it]
# 02/04/2020 09:43:32 PM Closing datasets
# 02/04/2020 09:43:32 PM Done!
# 02/04/2020 09:43:32 PM Preprocess validation dataset
# 02/04/2020 09:43:32 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_SP_M4K_valid.nc
# 02/04/2020 09:43:32 PM Reading input files
# 02/04/2020 09:43:32 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_minus4k/sp8fbp_minus4k.cam2.h2.0001-*-1*-00000.nc

# %% [markdown]
# ### Specific humidity, training and validation for (-4K) -- need to do validation as it was left

# %%
# !python preprocessing-11132019.py -c /home1/07064/tg863631/CBrain_project/PrepData/CI_SP_M4K.yml
# Out:
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 02/05/2020 02:35:03 PM Preprocess training dataset
# 02/05/2020 02:35:03 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_SP_M4K_train_temp.nc
# 02/05/2020 02:35:03 PM Reading input files
# 02/05/2020 02:35:03 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_minus4k/sp8fbp_minus4k.cam2.h2.0001-02-01-00000.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/preprocessing/convert_dataset_20191113.py:404: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds = xr.open_mfdataset(in_fns, decode_times=False, decode_cf=False, concat_dim='time')
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 02/05/2020 02:35:06 PM Crop levels
# 02/05/2020 02:35:06 PM Create stacked dataarray
# var is  QBP
# var is  TBP
# var is  PS
# var is  SOLIN
# var is  SHFLX
# var is  LHFLX
# var is  PHQ
# var is  TPHYSTND
# var is  FSNT
# var is  FSNS
# var is  FLNT
# var is  FLNS
# These time steps are cut: []
# 02/05/2020 02:35:06 PM Stack and reshape dataarray
# 02/05/2020 02:35:06 PM Save dataarray as /scratch/07064/tg863631/PrepData/CI_SP_M4K_train_temp.nc
# 02/05/2020 02:35:23 PM Done!
# 02/05/2020 02:35:23 PM Shuffle training dataset
# 02/05/2020 02:35:23 PM Start shuffling /scratch/07064/tg863631/PrepData/CI_SP_M4K_train_temp.nc into /scratch/07064/tg863631/PrepData/CI_SP_M4K_train_temp_shuffle.nc. Open and create datasets.
# 02/05/2020 02:35:23 PM Shuffle!
# 100%|█████████████████████████████████████████████| 1/1 [00:01<00:00,  1.07s/it]
# 02/05/2020 02:35:24 PM Closing datasets
# 02/05/2020 02:35:24 PM Done!
# 02/05/2020 02:35:24 PM Preprocess validation dataset
# 02/05/2020 02:35:24 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_SP_M4K_valid.nc
# 02/05/2020 02:35:24 PM Reading input files
# 02/05/2020 02:35:24 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_minus4k/sp8fbp_minus4k.cam2.h2.0001-*-*5-00000.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/preprocessing/convert_dataset_20191113.py:404: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds = xr.open_mfdataset(in_fns, decode_times=False, decode_cf=False, concat_dim='time')
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 02/05/2020 02:36:50 PM Crop levels
# 02/05/2020 02:36:50 PM Create stacked dataarray
# var is  QBP
# var is  TBP
# var is  PS
# var is  SOLIN
# var is  SHFLX
# var is  LHFLX
# var is  PHQ
# var is  TPHYSTND
# var is  FSNT
# var is  FSNS
# var is  FLNT
# var is  FLNS
# These time steps are cut: [  47   95  143  191  239  287  335  383  431  479  527  575  623  671
#   719  767  815  863  911  959 1007 1055 1103 1151 1199 1247 1295 1343
#  1391 1439 1487 1535 1583 1631 1679]
# 02/05/2020 02:36:51 PM Stack and reshape dataarray
# 02/05/2020 02:36:52 PM Save dataarray as /scratch/07064/tg863631/PrepData/CI_SP_M4K_valid.nc
# 02/05/2020 02:47:12 PM Done!
# 02/05/2020 02:47:12 PM Finish entire preprocessing script.

# %%
cd ../../
# Out:
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM

# %% [markdown]
# ### Specific humidity, norm file for (+4K)

# %%
# !python preprocessing-11132019.py -c /home1/07064/tg863631/CBrain_project/PrepData/CI_SP_P4K_NORM.yml
# Out:
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 02/05/2020 03:07:04 PM Preprocess training dataset
# 02/05/2020 03:07:04 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_SP_P4K_NORM_train.nc
# 02/05/2020 03:07:04 PM Reading input files
# 02/05/2020 03:07:04 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_4k/sp8fbp_4k.cam2.h2.0001-01-0*-00000.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/preprocessing/convert_dataset_20191113.py:404: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds = xr.open_mfdataset(in_fns, decode_times=False, decode_cf=False, concat_dim='time')
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 02/05/2020 03:07:25 PM Crop levels
# 02/05/2020 03:07:25 PM Create stacked dataarray
# var is  QBP
# var is  TBP
# var is  PS
# var is  SOLIN
# var is  SHFLX
# var is  LHFLX
# var is  PHQ
# var is  TPHYSTND
# var is  FSNT
# var is  FSNS
# var is  FLNT
# var is  FLNS
# These time steps are cut: []
# 02/05/2020 03:07:25 PM Stack and reshape dataarray
# 02/05/2020 03:07:26 PM Save dataarray as /scratch/07064/tg863631/PrepData/CI_SP_P4K_NORM_train.nc
# 02/05/2020 03:10:05 PM Done!
# 02/05/2020 03:10:05 PM Shuffle training dataset
# 02/05/2020 03:10:05 PM Start shuffling /scratch/07064/tg863631/PrepData/CI_SP_P4K_NORM_train.nc into /scratch/07064/tg863631/PrepData/CI_SP_P4K_NORM_train_shuffle.nc. Open and create datasets.
# 02/05/2020 03:10:06 PM Shuffle!
# 100%|█████████████████████████████████████████████| 1/1 [00:14<00:00, 14.21s/it]
# 02/05/2020 03:10:20 PM Closing datasets
# 02/05/2020 03:10:20 PM Done!
# 02/05/2020 03:10:20 PM Preprocess validation dataset
# 02/05/2020 03:10:20 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_SP_P4K_NORM_valid.nc
# 02/05/2020 03:10:20 PM Reading input files
# 02/05/2020 03:10:20 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_4k/sp8fbp_4k.cam2.h2.0001-01-0*-00000.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/preprocessing/convert_dataset_20191113.py:404: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds = xr.open_mfdataset(in_fns, decode_times=False, decode_cf=False, concat_dim='time')
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 02/05/2020 03:10:24 PM Crop levels
# 02/05/2020 03:10:24 PM Create stacked dataarray
# var is  QBP
# var is  TBP
# var is  PS
# var is  SOLIN
# var is  SHFLX
# var is  LHFLX
# var is  PHQ
# var is  TPHYSTND
# var is  FSNT
# var is  FSNS
# var is  FLNT
# var is  FLNS
# These time steps are cut: []
# 02/05/2020 03:10:24 PM Stack and reshape dataarray
# 02/05/2020 03:10:25 PM Save dataarray as /scratch/07064/tg863631/PrepData/CI_SP_P4K_NORM_valid.nc
# 02/05/2020 03:12:30 PM Done!
# 02/05/2020 03:12:30 PM Compute normalization file from train
# 02/05/2020 03:12:30 PM Start normalizing by creating dataset.
# 02/05/2020 03:12:30 PM Compute standard normalizations.
# 02/05/2020 03:13:05 PM Saving normalization file as /scratch/07064/tg863631/PrepData/CI_SP_P4K_NORM_norm.nc
# 02/05/2020 03:13:05 PM Done!
# 02/05/2020 03:13:05 PM Finish entire preprocessing script.

# %% [markdown]
# ### Specific humidity, training and validation for (+4K)

# %%
# !python preprocessing-11132019.py -c /home1/07064/tg863631/CBrain_project/PrepData/CI_SP_P4K.yml
# Out:
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 02/05/2020 03:45:49 PM Preprocess training dataset
# 02/05/2020 03:45:49 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_SP_P4K_train.nc
# 02/05/2020 03:45:49 PM Reading input files
# 02/05/2020 03:45:49 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_4k/sp8fbp_4k.cam2.h2.0001-*-0*-00000.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/preprocessing/convert_dataset_20191113.py:404: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds = xr.open_mfdataset(in_fns, decode_times=False, decode_cf=False, concat_dim='time')
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 02/05/2020 03:50:12 PM Crop levels
# 02/05/2020 03:50:12 PM Create stacked dataarray
# var is  QBP
# var is  TBP
# var is  PS
# var is  SOLIN
# var is  SHFLX
# var is  LHFLX
# var is  PHQ
# var is  TPHYSTND
# var is  FSNT
# var is  FSNS
# var is  FLNT
# var is  FLNS
# These time steps are cut: [ 431  863 1295 1727 2159 2591 3023 3455 3887 4319 4751]
# 02/05/2020 03:50:13 PM Stack and reshape dataarray
# 02/05/2020 03:50:17 PM Save dataarray as /scratch/07064/tg863631/PrepData/CI_SP_P4K_train.nc
# 02/05/2020 04:56:07 PM Done!
# 02/05/2020 04:56:08 PM Shuffle training dataset
# 02/05/2020 04:56:08 PM Start shuffling /scratch/07064/tg863631/PrepData/CI_SP_P4K_train.nc into /scratch/07064/tg863631/PrepData/CI_SP_P4K_train_shuffle.nc. Open and create datasets.
# 02/05/2020 04:56:16 PM Shuffle!
# 100%|█████████████████████████████████████████████| 5/5 [04:53<00:00, 58.76s/it]
# 02/05/2020 05:01:11 PM Closing datasets
# 02/05/2020 05:01:11 PM Done!
# 02/05/2020 05:01:11 PM Preprocess validation dataset
# 02/05/2020 05:01:11 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_SP_P4K_valid.nc
# 02/05/2020 05:01:11 PM Reading input files
# 02/05/2020 05:01:11 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_4k/sp8fbp_4k.cam2.h2.0001-*-*5-00000.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/preprocessing/convert_dataset_20191113.py:404: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds = xr.open_mfdataset(in_fns, decode_times=False, decode_cf=False, concat_dim='time')
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 02/05/2020 05:02:31 PM Crop levels
# 02/05/2020 05:02:31 PM Create stacked dataarray
# var is  QBP
# var is  TBP
# var is  PS
# var is  SOLIN
# var is  SHFLX
# var is  LHFLX
# var is  PHQ
# var is  TPHYSTND
# var is  FSNT
# var is  FSNS
# var is  FLNT
# var is  FLNS
# These time steps are cut: [  47   95  143  191  239  287  335  383  431  479  527  575  623  671
#   719  767  815  863  911  959 1007 1055 1103 1151 1199 1247 1295 1343
#  1391 1439 1487 1535 1583 1631 1679]
# 02/05/2020 05:02:31 PM Stack and reshape dataarray
# 02/05/2020 05:02:33 PM Save dataarray as /scratch/07064/tg863631/PrepData/CI_SP_P4K_valid.nc
# 02/05/2020 05:15:52 PM Done!
# 02/05/2020 05:15:52 PM Finish entire preprocessing script.

# %% [markdown]
# ### Relative humidity, norm file for (-4K)

# %%
# !python preprocessing-11132019.py -c /home1/07064/tg863631/CBrain_project/PrepData/CI_RH_M4K_NORM.yml
# Out:
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 02/05/2020 03:14:47 PM Preprocess training dataset
# 02/05/2020 03:14:47 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_RH_M4K_NORM_train.nc
# 02/05/2020 03:14:47 PM Reading input files
# 02/05/2020 03:14:47 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_minus4k/sp8fbp_minus4k.cam2.h2.0001-01-0*-00000.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/preprocessing/convert_dataset_20191113.py:404: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds = xr.open_mfdataset(in_fns, decode_times=False, decode_cf=False, concat_dim='time')
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 02/05/2020 03:15:06 PM Crop levels
# 02/05/2020 03:15:06 PM Create stacked dataarray
# var is  RH
# var is  TBP
# var is  PS
# var is  SOLIN
# var is  SHFLX
# var is  LHFLX
# var is  PHQ
# var is  TPHYSTND
# var is  FSNT
# var is  FSNS
# var is  FLNT
# var is  FLNS
# These time steps are cut: []
# 02/05/2020 03:18:16 PM Stack and reshape dataarray
# 02/05/2020 03:18:16 PM Save dataarray as /scratch/07064/tg863631/PrepData/CI_RH_M4K_NORM_train.nc
# 02/05/2020 03:24:19 PM Done!
# 02/05/2020 03:24:19 PM Shuffle training dataset
# 02/05/2020 03:24:19 PM Start shuffling /scratch/07064/tg863631/PrepData/CI_RH_M4K_NORM_train.nc into /scratch/07064/tg863631/PrepData/CI_RH_M4K_NORM_train_shuffle.nc. Open and create datasets.
# 02/05/2020 03:24:20 PM Shuffle!
# 100%|█████████████████████████████████████████████| 1/1 [00:43<00:00, 43.16s/it]
# 02/05/2020 03:25:04 PM Closing datasets
# 02/05/2020 03:25:04 PM Done!
# 02/05/2020 03:25:04 PM Preprocess validation dataset
# 02/05/2020 03:25:04 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_RH_M4K_NORM_valid.nc
# 02/05/2020 03:25:04 PM Reading input files
# 02/05/2020 03:25:04 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_minus4k/sp8fbp_minus4k.cam2.h2.0001-01-0*-00000.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/preprocessing/convert_dataset_20191113.py:404: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds = xr.open_mfdataset(in_fns, decode_times=False, decode_cf=False, concat_dim='time')
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 02/05/2020 03:25:16 PM Crop levels
# 02/05/2020 03:25:16 PM Create stacked dataarray
# var is  RH
# var is  TBP
# var is  PS
# var is  SOLIN
# var is  SHFLX
# var is  LHFLX
# var is  PHQ
# var is  TPHYSTND
# var is  FSNT
# var is  FSNS
# var is  FLNT
# var is  FLNS
# These time steps are cut: []
# 02/05/2020 03:28:20 PM Stack and reshape dataarray
# 02/05/2020 03:28:20 PM Save dataarray as /scratch/07064/tg863631/PrepData/CI_RH_M4K_NORM_valid.nc
# 02/05/2020 03:34:11 PM Done!
# 02/05/2020 03:34:11 PM Compute normalization file from train
# 02/05/2020 03:34:11 PM Start normalizing by creating dataset.
# 02/05/2020 03:34:12 PM Compute standard normalizations.
# 02/05/2020 03:35:20 PM Saving normalization file as /scratch/07064/tg863631/PrepData/CI_RH_M4K_NORM_norm.nc
# 02/05/2020 03:35:20 PM Done!
# 02/05/2020 03:35:20 PM Finish entire preprocessing script.

# %% [markdown]
# ## Build and train models on (-4K) with and without the first input rescaling

# %% [markdown]
# ### Generator using specific humidity inputs at (-4K)

# %%
scale_dict = load_pickle('/home1/07064/tg863631/CBrain_project/CBRAIN-CAM/nn_config/scale_dicts/009_Wm2_scaling.pkl')

# %%
in_vars = ['QBP','TBP','PS', 'SOLIN', 'SHFLX', 'LHFLX']
out_vars = ['PHQ','TPHYSTND','FSNT', 'FSNS', 'FLNT', 'FLNS']

# %%
TRAINDIR = '/scratch/07064/tg863631/PrepData/'
TRAINFILE = 'CI_SP_M4K_train_shuffle.nc'
NORMFILE = 'CI_SP_M4K_NORM_norm.nc'
VALIDFILE = 'CI_SP_M4K_valid.nc'

# %%
train_gen = DataGenerator(
    data_fn = TRAINDIR+TRAINFILE,
    input_vars = in_vars,
    output_vars = out_vars,
    norm_fn = TRAINDIR+NORMFILE,
    input_transform = ('mean', 'maxrs'),
    output_transform = scale_dict,
    batch_size=1024,
    shuffle=True
)

# %%
valid_gen = DataGenerator(
    data_fn = TRAINDIR+VALIDFILE,
    input_vars = in_vars,
    output_vars = out_vars,
    norm_fn = TRAINDIR+NORMFILE,
    input_transform = ('mean', 'maxrs'),
    output_transform = scale_dict,
    batch_size=1024,
    shuffle=True
)

# %%
print(valid_gen[50][0].shape)
print(train_gen[50][1].shape)
print(valid_gen[78][0].shape)
print(valid_gen[78][1].shape)
# Out:
# (1024, 64)
# (1024, 64)
# (1024, 64)
# (1024, 64)

# %% [markdown]
# ### Generator using relative humidity inputs

# %%
scale_dict_RH = load_pickle('/home1/07064/tg863631/CBrain_project/CBRAIN-CAM/nn_config/scale_dicts/009_Wm2_scaling.pkl')

# %%
scale_dict_RH['RH'] = 0.01*L_S/G, # Arbitrary 0.1 factor as specific humidity is generally below 2%

# %%
in_vars_RH = ['RH','TBP','PS', 'SOLIN', 'SHFLX', 'LHFLX']
out_vars_RH = ['PHQ','TPHYSTND','FSNT', 'FSNS', 'FLNT', 'FLNS']

# %%
TRAINFILE_RH = 'CI_RH_M4K_NORM_train_shuffle.nc'
NORMFILE_RH = 'CI_RH_M4K_NORM_norm.nc'
VALIDFILE_RH = 'CI_RH_M4K_NORM_valid.nc'

# %%
train_gen_RH = DataGenerator(
    data_fn = TRAINDIR+TRAINFILE_RH,
    input_vars = in_vars_RH,
    output_vars = out_vars_RH,
    norm_fn = TRAINDIR+NORMFILE_RH,
    input_transform = ('mean', 'maxrs'),
    output_transform = scale_dict_RH,
    batch_size=1024,
    shuffle=True
)

# %%
print(train_gen_RH[50][0].shape)
print(train_gen_RH[50][1].shape)
print(train_gen_RH[78][0].shape)
print(train_gen_RH[78][1].shape)
# Out:
# (1024, 64)
# (1024, 64)
# (1024, 64)
# (1024, 64)

# %% [markdown]
# ### Build "brute-force" model

# %%
inp = Input(shape=(64,))
densout = Dense(128, activation='linear')(inp)
densout = LeakyReLU(alpha=0.3)(densout)
for i in range (6):
    densout = Dense(128, activation='linear')(densout)
    densout = LeakyReLU(alpha=0.3)(densout)
out = Dense(64, activation='linear')(densout)
Brute_force = tf.keras.models.Model(inp, out)

# %%
Brute_force.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# =================================================================
# Total params: 115,648
# Trainable params: 115,648
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Build model converting specific humidity to relative humidity as inputs

# %%
# Moist thermodynamics library adapted to tf
def eliq(T):
    a_liq = np.float32(np.array([-0.976195544e-15,-0.952447341e-13,\
                                 0.640689451e-10,\
                      0.206739458e-7,0.302950461e-5,0.264847430e-3,\
                      0.142986287e-1,0.443987641,6.11239921]));
    c_liq = np.float32(-80.0)
    T0 = np.float32(273.16)
    return np.float32(100.0)*tfm.polyval(a_liq,tfm.maximum(c_liq,T-T0))

def eice(T):
    a_ice = np.float32(np.array([0.252751365e-14,0.146898966e-11,0.385852041e-9,\
                      0.602588177e-7,0.615021634e-5,0.420895665e-3,\
                      0.188439774e-1,0.503160820,6.11147274]));
    c_ice = np.float32(np.array([273.15,185,-100,0.00763685,0.000151069,7.48215e-07]))
    T0 = np.float32(273.16)
    return tf.where(T>c_ice[0],eliq(T),\
                   tf.where(T<=c_ice[1],np.float32(100.0)*(c_ice[3]+tfm.maximum(c_ice[2],T-T0)*\
                   (c_ice[4]+tfm.maximum(c_ice[2],T-T0)*c_ice[5])),\
                           np.float32(100.0)*tfm.polyval(a_ice,T-T0)))

def esat(T):
    T0 = np.float32(273.16)
    T00 = np.float32(253.16)
    omtmp = (T-T00)/(T0-T00)
    omega = tfm.maximum(np.float32(0.0),tfm.minimum(np.float32(1.0),omtmp))

    return tf.where(T>T0,eliq(T),tf.where(T<T00,eice(T),(omega*eliq(T)+(1-omega)*eice(T))))

def qv(T,RH,P0,PS,hyam,hybm):
    
    R = np.float32(287.0)
    Rv = np.float32(461.0)
    p = P0 * hyam + PS[:, None] * hybm # Total pressure (Pa)
    
    T = tf.cast(T,tf.float32)
    RH = tf.cast(RH,tf.float32)
    p = tf.cast(p,tf.float32)
    
    return R*esat(T)*RH/(Rv*p)
    # DEBUG 1
    # return esat(T)
    
def RH(T,qv,P0,PS,hyam,hybm):
    R = np.float32(287.0)
    Rv = np.float32(461.0)
    p = P0 * hyam + PS[:, None] * hybm # Total pressure (Pa)
    
    T = tf.cast(T,tf.float32)
    qv = tf.cast(qv,tf.float32)
    p = tf.cast(p,tf.float32)
    
    return Rv*p*qv/(R*esat(T))

# %%
class QV2RH(Layer):
    def __init__(self, inp_subQ, inp_divQ, inp_subRH, inp_divRH, hyam, hybm, **kwargs):
        """
        Call using ([input])
        Assumes
        prior: [QBP, 
        TBP, PS, SOLIN, SHFLX, LHFLX]
        Returns
        post(erior): [RHBP,
        TBP, PS, SOLIN, SHFLX, LHFLX]
        Arguments:
        inp_subQ = Normalization based on input with specific humidity (subtraction constant)
        inp_divQ = Normalization based on input with specific humidity (division constant)
        int_subRH = Normalization based on input with relative humidity (subtraction constant)
        inp_divRH = Normalization based on input with relative humidity (division constant)
        hyam = Constant a for pressure based on mid-levels
        hybm = Constant b for pressure based on mid-levels
        """
        self.inp_subQ, self.inp_divQ, self.inp_subRH, self.inp_divRH, self.hyam, self.hybm = \
            np.array(inp_subQ), np.array(inp_divQ), np.array(inp_subRH), np.array(inp_divRH), \
        np.array(hyam), np.array(hybm)
        # Define variable indices here
        # Input
        self.QBP_idx = slice(0,30)
        self.TBP_idx = slice(30,60)
        self.PS_idx = 60
        self.SHFLX_idx = 62
        self.LHFLX_idx = 63

        super().__init__(**kwargs)

    def build(self, input_shape):
        super().build(input_shape)

    def get_config(self):
        config = {'inp_subQ': list(self.inp_subQ), 'inp_divQ': list(self.inp_divQ),
                  'inp_subRH': list(self.inp_subRH), 'inp_divRH': list(self.inp_divRH),
                  'hyam': list(self.hyam),'hybm': list(self.hybm)}
        base_config = super().get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
    def call(self, arrs):
        prior = arrs
        
        Tprior = prior[:,self.TBP_idx]*self.inp_divQ[self.TBP_idx]+self.inp_subQ[self.TBP_idx]
        qvprior = prior[:,self.QBP_idx]*self.inp_divQ[self.QBP_idx]+self.inp_subQ[self.QBP_idx]
        PSprior = prior[:,self.PS_idx]*self.inp_divQ[self.PS_idx]+self.inp_subQ[self.PS_idx]
        RHprior = (RH(Tprior,qvprior,P0,PSprior,self.hyam,self.hybm)-\
                    self.inp_subRH[self.QBP_idx])/self.inp_divRH[self.QBP_idx]
        
        post = tf.concat([tf.cast(RHprior,tf.float32),prior[:,30:]], axis=1)
        
        return post

    def compute_output_shape(self,input_shape):
        """Input shape + 1"""
        return (input_shape[0][0])

# %%
path = '/home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/'
path_hyam = 'hyam_hybm.pkl'
hf = open(path+path_hyam,'rb')
hyam,hybm = pickle.load(hf)

# %%
inp = Input(shape=(64,))
inpRH = QV2RH(inp_subQ=train_gen.input_transform.sub, 
              inp_divQ=train_gen.input_transform.div, 
              inp_subRH=train_gen_RH.input_transform.sub, 
              inp_divRH=train_gen_RH.input_transform.div, 
              hyam=hyam, hybm=hybm)(inp)
densout = Dense(128, activation='linear')(inpRH)
densout = LeakyReLU(alpha=0.3)(densout)
for i in range (6):
    densout = Dense(128, activation='linear')(densout)
    densout = LeakyReLU(alpha=0.3)(densout)
out = Dense(64, activation='linear')(densout)
Input_RH = tf.keras.models.Model(inp, out)

# %%
Input_RH.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 64)                0
# _________________________________________________________________
# q_v2rh (QV2RH)               (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                8256
# =================================================================
# Total params: 115,648
# Trainable params: 115,648
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile and train both models for Nep (e.g. 10) epochs

# %%
path_HDF5 = '/scratch/07064/tg863631/models/'
earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')
mcp_save_BF = ModelCheckpoint(path_HDF5+'CI01_BF.hdf5',save_best_only=True, monitor='val_loss', mode='min')
mcp_save_RH = ModelCheckpoint(path_HDF5+'CI01_RH.hdf5',save_best_only=True, monitor='val_loss', mode='min')

# %%
Brute_force.compile(tf.keras.optimizers.Adam(), loss=mse)
# Input_RH.compile(tf.keras.optimizers.Adam(), loss=mse)

# %%
Nep = 2
Brute_force.load_weights(path_HDF5+'CI01_BF.hdf5')
Brute_force.fit_generator(train_gen, epochs=Nep, validation_data=valid_gen,\
              callbacks=[earlyStopping, mcp_save_BF])
# Out:
# Epoch 1/2
# 41376/41376 [==============================] - 4279s 103ms/step - loss: 350.5246 - val_loss: 345.0353
# Epoch 2/2
#  3509/41376 [=>............................] - ETA: 50:01 - loss: 349.6673

# %%
Nep = 10
Input_RH.fit_generator(train_gen, epochs=Nep, validation_data=valid_gen,\
              callbacks=[earlyStopping, mcp_save_RH])

# %% [markdown]
# ## Build model diagnostics objects¶

# %% [markdown]
# ## Input Rescaling 2.1: Temperature difference from near-surface

# %% [markdown]
# ### Add code to pre-process the temperature

# %% [markdown]
# Added to [https://github.com/tbeucler/CBRAIN-CAM/blob/master/cbrain/preprocessing/convert_dataset_20191113.py]
# def compute_TfromNS(ds):
#     return compute_bp(ds,'TBP')-compute_bp(ds,'TBP')[:,-1,:,:]
# Further down:
#         elif var == 'TfromNS':
#             da = compute_TfromNS(ds)
# Here's the configuration file CI_TNS_M4K_NORM.yml:
# #Climate-invariant - Temperature minus Near-surface temperature - Minus 4K - Norm
# vars : [QBP, TfromNS, PS, SOLIN, SHFLX, LHFLX, PHQ, TPHYSTND, FSNT, FSNS, FLNT, FLNS]
#
# in_dir : /project/meteo/w2w/A6/S.Rasp/SP-CAM/sp8fbp_minus4k
# in_fns : sp8fbp_minus4k.cam2.h2.0001-01-0*-00000.nc
#
# out_dir: /local/Tom.Beucler/SPCAM_PHYS/
# out_fn: CI_TNS_M4K_NORM_train.nc
#
# val_in_fns: sp8fbp_minus4k.cam2.h2.0001-01-0*-00000.nc
# val_out_fn: CI_TNS_M4K_NORM_valid.nc
#
# norm_fn: CI_TNS_M4K_NORM_norm.nc

# %%
# !python preprocessing-11132019.py -c /home1/07064/tg863631/CBrain_project/PrepData/CI_TNS_M4K_NORM.yml
# Out:
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 02/07/2020 07:44:45 PM Preprocess training dataset
# 02/07/2020 07:44:45 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_TNS_M4K_NORM_train.nc
# 02/07/2020 07:44:45 PM Reading input files
# 02/07/2020 07:44:45 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_minus4k/sp8fbp_minus4k.cam2.h2.0001-01-0*-00000.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/preprocessing/convert_dataset_20191113.py:409: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds = xr.open_mfdataset(in_fns, decode_times=False, decode_cf=False, concat_dim='time')
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 02/07/2020 07:45:08 PM Crop levels
# 02/07/2020 07:45:08 PM Create stacked dataarray
# var is  QBP
# var is  TfromNS
# var is  PS
# var is  SOLIN
# var is  SHFLX
# var is  LHFLX
# var is  PHQ
# var is  TPHYSTND
# var is  FSNT
# var is  FSNS
# var is  FLNT
# var is  FLNS
# These time steps are cut: []
# 02/07/2020 07:45:08 PM Stack and reshape dataarray
# 02/07/2020 07:45:09 PM Save dataarray as /scratch/07064/tg863631/PrepData/CI_TNS_M4K_NORM_train.nc
# 02/07/2020 07:47:41 PM Done!
# 02/07/2020 07:47:41 PM Shuffle training dataset
# 02/07/2020 07:47:41 PM Start shuffling /scratch/07064/tg863631/PrepData/CI_TNS_M4K_NORM_train.nc into /scratch/07064/tg863631/PrepData/CI_TNS_M4K_NORM_train_shuffle.nc. Open and create datasets.
# 02/07/2020 07:47:41 PM Shuffle!
# 100%|█████████████████████████████████████████████| 1/1 [00:10<00:00, 10.00s/it]
# 02/07/2020 07:47:51 PM Closing datasets
# 02/07/2020 07:47:51 PM Done!
# 02/07/2020 07:47:51 PM Preprocess validation dataset
# 02/07/2020 07:47:51 PM Start preprocessing file /scratch/07064/tg863631/PrepData/CI_TNS_M4K_NORM_valid.nc
# 02/07/2020 07:47:51 PM Reading input files
# 02/07/2020 07:47:51 PM Reading input file /scratch/05823/tg851228/CBRAIN/sp8fbp_minus4k/sp8fbp_minus4k.cam2.h2.0001-01-0*-00000.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/cbrain/preprocessing/convert_dataset_20191113.py:409: FutureWarning: In xarray version 0.15 the default behaviour of `open_mfdataset`
# will change. To retain the existing behavior, pass
# combine='nested'. To use future default behavior, pass
# combine='by_coords'. See
# http://xarray.pydata.org/en/stable/combining.html#combining-multi
#
#   ds = xr.open_mfdataset(in_fns, decode_times=False, decode_cf=False, concat_dim='time')
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/xarray/backends/api.py:933: FutureWarning: Also `open_mfdataset` will no longer accept a `concat_dim` argument.
# To get equivalent behaviour from now on please use the new
# `combine_nested` function instead (or the `combine='nested'` option to
# `open_mfdataset`).The datasets supplied have global dimension coordinates. You may want
# to use the new `combine_by_coords` function (or the
# `combine='by_coords'` option to `open_mfdataset`) to order the datasets
# before concatenation. Alternatively, to continue concatenating based
# on the order the datasets are supplied in future, please use the new
# `combine_nested` function (or the `combine='nested'` option to
# open_mfdataset).
#   from_openmfds=True,
# 02/07/2020 07:47:55 PM Crop levels
# 02/07/2020 07:47:55 PM Create stacked dataarray
# var is  QBP
# var is  TfromNS
# var is  PS
# var is  SOLIN
# var is  SHFLX
# var is  LHFLX
# var is  PHQ
# var is  TPHYSTND
# var is  FSNT
# var is  FSNS
# var is  FLNT
# var is  FLNS
# These time steps are cut: []
# 02/07/2020 07:47:55 PM Stack and reshape dataarray
# 02/07/2020 07:47:56 PM Save dataarray as /scratch/07064/tg863631/PrepData/CI_TNS_M4K_NORM_valid.nc
# 02/07/2020 07:49:52 PM Done!
# 02/07/2020 07:49:52 PM Compute normalization file from train
# 02/07/2020 07:49:52 PM Start normalizing by creating dataset.
# 02/07/2020 07:49:52 PM Compute standard normalizations.
# 02/07/2020 07:50:22 PM Saving normalization file as /scratch/07064/tg863631/PrepData/CI_TNS_M4K_NORM_norm.nc
# 02/07/2020 07:50:22 PM Done!
# 02/07/2020 07:50:22 PM Finish entire preprocessing script.

# %% [markdown]
# ### Code tensorflow layer to subtract the near-surface temperature from the temperature within the network

# %%
class T2TmTNS(Layer):
    def __init__(self, inp_subT, inp_divT, inp_subTNS, inp_divTNS, hyam, hybm, **kwargs):
        """
        From temperature to (temperature)-(near-surface temperature)
        Call using ([input])
        Assumes
        prior: [QBP, 
        TBP, 
        PS, SOLIN, SHFLX, LHFLX]
        Returns
        post(erior): [QBP,
        TfromNS, 
        PS, SOLIN, SHFLX, LHFLX]
        Arguments:
        inp_subT = Normalization based on input with temperature (subtraction constant)
        inp_divT = Normalization based on input with temperature (division constant)
        inp_subTNS = Normalization based on input with (temp - near-sur temp) (subtraction constant)
        inp_divTNS = Normalization based on input with (temp - near-sur temp) (division constant)
        hyam = Constant a for pressure based on mid-levels
        hybm = Constant b for pressure based on mid-levels
        """
        self.inp_subT, self.inp_divT, self.inp_subTNS, self.inp_divTNS, self.hyam, self.hybm = \
            np.array(inp_subT), np.array(inp_divT), np.array(inp_subTNS), np.array(inp_divTNS), \
        np.array(hyam), np.array(hybm)
        # Define variable indices here
        # Input
        self.QBP_idx = slice(0,30)
        self.TBP_idx = slice(30,60)
        self.PS_idx = 60
        self.SHFLX_idx = 62
        self.LHFLX_idx = 63

        super().__init__(**kwargs)

    def build(self, input_shape):
        super().build(input_shape)

    def get_config(self):
        config = {'inp_subT': list(self.inp_subT), 'inp_divT': list(self.inp_divT),
                  'inp_subTNS': list(self.inp_subTNS), 'inp_divTNS': list(self.inp_divTNS),
                  'hyam': list(self.hyam),'hybm': list(self.hybm)}
        base_config = super().get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
    def call(self, arrs):
        prior = arrs
        
        Tprior = prior[:,self.TBP_idx]*self.inp_divT[self.TBP_idx]+self.inp_subT[self.TBP_idx]
        
        Tile_dim = tf.constant([1,30],tf.int32)
        TNSprior = ((Tprior-tf.tile(tf.expand_dims(Tprior[:,-1],axis=1),Tile_dim))-\
                    self.inp_subTNS[self.TBP_idx])/\
        self.inp_divTNS[self.TBP_idx]
        
        post = tf.concat([prior[:,:30],tf.cast(TNSprior,tf.float32),prior[:,60:]], axis=1)
        
        return post

    def compute_output_shape(self,input_shape):
        """Input shape + 1"""
        return (input_shape[0][0])

# %% [markdown]
# ### Build Generators

# %% [markdown]
# ### Generator using specific humidity inputs

# %%
scale_dict = load_pickle('./nn_config/scale_dicts/009_Wm2_scaling.pkl')

in_vars = ['QBP','TBP','PS', 'SOLIN', 'SHFLX', 'LHFLX']
out_vars = ['PHQ','TPHYSTND','FSNT', 'FSNS', 'FLNT', 'FLNS']


TRAINFILE = 'CI_SP_M4K_train_shuffle.nc'
NORMFILE = 'CI_SP_M4K_NORM_norm.nc'
VALIDFILE = 'CI_SP_M4K_valid.nc'


train_gen = DataGenerator(
    data_fn = TRAINDIR+TRAINFILE,
    input_vars = in_vars,
    output_vars = out_vars,
    norm_fn = TRAINDIR+NORMFILE,
    input_transform = ('mean', 'maxrs'),
    output_transform = scale_dict,
    batch_size=1024,
    shuffle=True
)

valid_gen = DataGenerator(
    data_fn = TRAINDIR+VALIDFILE,
    input_vars = in_vars,
    output_vars = out_vars,
    norm_fn = TRAINDIR+NORMFILE,
    input_transform = ('mean', 'maxrs'),
    output_transform = scale_dict,
    batch_size=1024,
    shuffle=True
)

# %%
print(train_gen[50][0].shape)
print(train_gen[50][1].shape)
print(valid_gen[78][0].shape)
print(valid_gen[78][1].shape)
# Out:
# (1024, 64)
# (1024, 64)
# (1024, 64)
# (1024, 64)

# %% [markdown]
# ### Generator using (T-T_{near-surface}) inputs

# %%
in_vars = ['QBP','TfromNS','PS', 'SOLIN', 'SHFLX', 'LHFLX']
out_vars = ['PHQ','TPHYSTND','FSNT', 'FSNS', 'FLNT', 'FLNS']

# %%
TRAINFILE_TNS = 'CI_TNS_M4K_NORM_train_shuffle.nc'
NORMFILE_TNS = 'CI_TNS_M4K_NORM_norm.nc'
VALIDFILE_TNS = 'CI_TNS_M4K_NORM_valid.nc'

# %%
train_gen_TNS = DataGenerator(
    data_fn = TRAINDIR+TRAINFILE_TNS,
    input_vars = in_vars,
    output_vars = out_vars,
    norm_fn = TRAINDIR+NORMFILE_TNS,
    input_transform = ('mean', 'maxrs'),
    output_transform = scale_dict,
    batch_size=1024,
    shuffle=True
)

# %%
print(train_gen_TNS[50][0].shape)
print(train_gen_TNS[50][1].shape)
print(train_gen_TNS[78][0].shape)
print(train_gen_TNS[78][1].shape)
# Out:
# (1024, 64)
# (1024, 64)
# (1024, 64)
# (1024, 64)

# %% [markdown]
# ### Generator using RH inputs

# %%
scale_dict_RH = load_pickle('./nn_config/scale_dicts/009_Wm2_scaling.pkl')

scale_dict_RH['RH'] = 0.01*L_S/G, # Arbitrary 0.1 factor as specific humidity is generally below 2%

in_vars_RH = ['RH','TBP','PS', 'SOLIN', 'SHFLX', 'LHFLX']
out_vars_RH = ['PHQ','TPHYSTND','FSNT', 'FSNS', 'FLNT', 'FLNS']

TRAINFILE_RH = 'CI_RH_M4K_NORM_train_shuffle.nc'
NORMFILE_RH = 'CI_RH_M4K_NORM_norm.nc'
VALIDFILE_RH = 'CI_RH_M4K_NORM_valid.nc'

train_gen_RH = DataGenerator(
    data_fn = TRAINDIR+TRAINFILE_RH,
    input_vars = in_vars_RH,
    output_vars = out_vars_RH,
    norm_fn = TRAINDIR+NORMFILE_RH,
    input_transform = ('mean', 'maxrs'),
    output_transform = scale_dict_RH,
    batch_size=1024,
    shuffle=True
)

# %%
print(train_gen_RH[50][0].shape)
print(train_gen_RH[50][1].shape)
print(train_gen_RH[78][0].shape)
print(train_gen_RH[78][1].shape)
# Out:
# (1024, 64)
# (1024, 64)
# (1024, 64)
# (1024, 64)

# %% [markdown]
# ### Build model converting temperature to (temperature-temperature_{NS}) as inputs

# %% [markdown]
# ### Replace T with T-Tns

# %%
inp = Input(shape=(64,))
inpTNS = T2TmTNS(inp_subT=train_gen.input_transform.sub, 
              inp_divT=train_gen.input_transform.div, 
              inp_subTNS=train_gen_TNS.input_transform.sub, 
              inp_divTNS=train_gen_TNS.input_transform.div, 
              hyam=hyam, hybm=hybm)(inp)
densout = Dense(128, activation='linear')(inpTNS)
densout = LeakyReLU(alpha=0.3)(densout)
for i in range (6):
    densout = Dense(128, activation='linear')(densout)
    densout = LeakyReLU(alpha=0.3)(densout)
out = Dense(64, activation='linear')(densout)
Input_TNS = tf.keras.models.Model(inp, out)

# %%
Input_TNS.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 64)                0
# _________________________________________________________________
# t2_tm_tns (T2TmTNS)          (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# =================================================================
# Total params: 115,648
# Trainable params: 115,648
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Replace both T and q

# %%
inp2 = Input(shape=(64,))
inpRH = QV2RH(inp_subQ=train_gen.input_transform.sub, 
              inp_divQ=train_gen.input_transform.div, 
              inp_subRH=train_gen_RH.input_transform.sub, 
              inp_divRH=train_gen_RH.input_transform.div, 
              hyam=hyam, hybm=hybm)(inp2)
inpTNS = T2TmTNS(inp_subT=train_gen.input_transform.sub, 
              inp_divT=train_gen.input_transform.div, 
              inp_subTNS=train_gen_TNS.input_transform.sub, 
              inp_divTNS=train_gen_TNS.input_transform.div, 
              hyam=hyam, hybm=hybm)(inpRH)
densout = Dense(128, activation='linear')(inpTNS)
densout = LeakyReLU(alpha=0.3)(densout)
for i in range (6):
    densout = Dense(128, activation='linear')(densout)
    densout = LeakyReLU(alpha=0.3)(densout)
out2 = Dense(64, activation='linear')(densout)
Input_RH_TNS = tf.keras.models.Model(inp2, out2)

# %%
Input_RH_TNS.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 64)                0
# _________________________________________________________________
# q_v2rh (QV2RH)               (None, 64)                0
# _________________________________________________________________
# t2_tm_tns_1 (T2TmTNS)        (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 64)                8256
# =================================================================
# Total params: 115,648
# Trainable params: 115,648
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile and train both models

# %%
path_HDF5 = '/scratch/07064/tg863631/models/'
earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')
mcp_save_TNS = ModelCheckpoint(path_HDF5+'CI01_TNS.hdf5',save_best_only=True, monitor='val_loss', mode='min')
mcp_save_RH_TNS = ModelCheckpoint(path_HDF5+'CI01_RH_TNS.hdf5',save_best_only=True, monitor='val_loss', mode='min')

# %%
Input_TNS.compile(tf.keras.optimizers.Adam(), loss=mse)
Input_RH_TNS.compile(tf.keras.optimizers.Adam(), loss=mse)

# %%
Nep = 10
Input_TNS.fit_generator(train_gen, epochs=Nep, validation_data=valid_gen,\
              callbacks=[earlyStopping, mcp_save_TNS])
# Out:
# Epoch 1/10
#    32/41376 [..............................] - ETA: 2:44:51 - loss: 5078.6973
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-ed6506c935a4> in <module>
#       1 Nep = 10
#       2 Input_TNS.fit_generator(train_gen, epochs=Nep, validation_data=valid_gen,\
# ----> 3               callbacks=[earlyStopping, mcp_save_TNS])
#
# ~/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2175         use_multiprocessing=use_multiprocessing,
#    2176         shuffle=shuffle,
# -> 2177         initial_epoch=initial_epoch)
#    2178
#    2179   def evaluate_generator(self,
#
# ~/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     174
#     175         outs = model.train_on_batch(
# --> 176             x, y, sample_weight=sample_weight, class_weight=class_weight)
#     177
#     178         if not isinstance(outs, list):
#
# ~/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1938
#    1939       self._make_train_function()
# -> 1940       outputs = self.train_function(ins)
#    1941
#    1942     if len(outputs) == 1:
#
# ~/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    2984
#    2985     fetched = self._callable_fn(*array_vals,
# -> 2986                                 run_metadata=self.run_metadata)
#    2987     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    2988     return fetched[:len(self.outputs)]
#
# ~/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
Nep = 10
Input_RH_TNS.fit_generator(train_gen, epochs=Nep, validation_data=valid_gen,\
              callbacks=[earlyStopping, mcp_save_RH_TNS])

# %% [markdown]
# ## Build model diagnostics objects

# %%
from climate_invariant import *

# %%
path_HDF5 = '/scratch/07064/tg863631/models/' # Path to NN weights
config_file = 'CI_SP_M4K_CONFIG.yml' # Configuration file
data_file = ['CI_SP_M4K_valid.nc','CI_SP_P4K_valid.nc'] # Validation/test data sets
NNarray = ['CI01_TNS.hdf5','CI01_RH_TNS.hdf5'] # NN to evaluate
NNname = ['TNS','TNS RH'] # Name of NNs for plotting
dict_lay = {'SurRadLayer':SurRadLayer,'MassConsLayer':MassConsLayer,'EntConsLayer':EntConsLayer, 
            'T2TmTNS':T2TmTNS,'QV2RH':QV2RH,'eliq':eliq,'eice':eice,'esat':esat,'qv':qv,'RH':RH}

# %%
# Indices of different variables
PHQ_idx = slice(0,30)
TPHYSTND_idx = slice(30,60)

# %% [markdown]
# Build model diagnostics object for each NN and each validation/test dataset

# %%
NN = {}; md = {};
# %cd $TRAINDIR/HDF5_DATA
for i,NNs in enumerate(NNarray):
    print('NN name is ',NNs)
    path = path_HDF5+NNs
    NN[NNs] = load_model(path,custom_objects=dict_lay)
    md[NNs] = {}
    for j,data in enumerate(data_file):
        print('data name is ',data)
        md[NNs][data[6:-3]] = ModelDiagnostics(NN[NNs],
                                                '/home1/07064/tg863631/CBrain_project/PrepData/'+config_file,
                                                TRAINDIR+data)
# Out:
# NN name is  CI01_TNS.hdf5
# data name is  CI_SP_M4K_valid.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/notebooks/ankitesh_devlog/cbrain/model_diagnostics.py:25: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)
# data name is  CI_SP_P4K_valid.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/notebooks/ankitesh_devlog/cbrain/model_diagnostics.py:25: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)
# NN name is  CI01_RH_TNS.hdf5
# data name is  CI_SP_M4K_valid.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/notebooks/ankitesh_devlog/cbrain/model_diagnostics.py:25: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)
# data name is  CI_SP_P4K_valid.nc
# /home1/07064/tg863631/CBrain_project/CBRAIN-CAM/notebooks/ankitesh_devlog/cbrain/model_diagnostics.py:25: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)

# %% [markdown]
# Loop over timesteps of the validation/test datasets and concatenate the prediction/truth of the networks. Note that the truths are the same for different NNs because we use the same inputs & outputs.

# %%
lat_ind = np.arange(26,40)
iini = 1000 # Initial time to sample
iend = iini+47 # One day later

diagno = {} # Diagnostics structure
diagno['truth'] = {} # Diagnostics structure for the truth
for i,NNs in enumerate(NNarray):
    print('i=',i,'& NNs=',NNs,'         ')
    diagno[NNs] = {} # Diagnostics structure for each NN
    for j,data in enumerate(data_file):
        diagno[NNs][data[6:-3]] = {} # Diagnostics structure for each data file
        if i==0: diagno['truth'][data[6:-3]] = {}
        print('j=',j,'& data=',data,'         ',end='\r')
        for itime in tqdm(np.arange(iini,iend)):
            # Get input, prediction and truth from NN
            inp, p, truth = md[NNs][data[6:-3]].get_inp_pred_truth(itime)  # [lat, lon, var, lev]
            # Get convective heating and moistening for each NN
            if itime==iini:
                if i==0:
                    diagno['truth'][data[6:-3]]['PHQ'] = md[NNs][data[6:-3]].reshape_ngeo(truth[:,PHQ_idx])[lat_ind,:,:,np.newaxis]
                    diagno['truth'][data[6:-3]]['TPHYSTND'] = md[NNs][data[6:-3]].reshape_ngeo(truth[:,TPHYSTND_idx])[lat_ind,:,:,np.newaxis]
                diagno[NNs][data[6:-3]]['PHQ'] = md[NNs][data[6:-3]].reshape_ngeo(p[:,PHQ_idx])[lat_ind,:,:,np.newaxis]
                diagno[NNs][data[6:-3]]['TPHYSTND'] = md[NNs][data[6:-3]].reshape_ngeo(p[:,TPHYSTND_idx])[lat_ind,:,:,np.newaxis]
            else:
                for istr,field in enumerate(['PHQ','TPHYSTND']):
                    if field=='PHQ': ind_field = PHQ_idx
                    elif field=='TPHYSTND': ind_field = TPHYSTND_idx
                    diagno[NNs][data[6:-3]][field] = np.concatenate((diagno[NNs][data[6:-3]][field],
                                                         md[NNs][data[6:-3]].\
                                                         reshape_ngeo(p[:,ind_field])[lat_ind,:,:,np.newaxis]),
                                                        axis=3)
                    if i==0:
                        diagno['truth'][data[6:-3]][field] = np.concatenate((diagno['truth'][data[6:-3]][field],
                                                                 md[NNs][data[6:-3]].\
                                                                 reshape_ngeo(truth[:,ind_field])[lat_ind,:,:,np.newaxis]),
                                                                axis=3)
# Out:
# i= 0 & NNs= CI01_TNS.hdf5
# j= 0 & data= CI_SP_M4K_valid.nc
# /home1/07064/tg863631/anaconda3/envs/CbrainCustomLayer/lib/python3.6/site-packages/ipykernel_launcher.py:14: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=47.0), HTML(value='')))
# j= 1 & data= CI_SP_P4K_valid.nc
# HBox(children=(FloatProgress(value=0.0, max=47.0), HTML(value='')))
# i= 1 & NNs= CI01_RH_TNS.hdf5
# j= 0 & data= CI_SP_M4K_valid.nc
# HBox(children=(FloatProgress(value=0.0, max=47.0), HTML(value='')))
# j= 1 & data= CI_SP_P4K_valid.nc
# HBox(children=(FloatProgress(value=0.0, max=47.0), HTML(value='')))

# %%
print(diagno)
# Out:
# {'truth': {'M4K_valid': {'PHQ': array([[[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-2.87265957e-05, -2.43754985e-05, -1.72851724e-05, ...,
#            1.03441744e-05,  5.11375720e-06,  4.54533347e-06],
#          ...,
#          [-1.57719917e+01,  2.16122398e+01, -3.74761734e+01, ...,
#            2.24462566e+01,  9.74743176e+00,  7.38942194e+00],
#          [ 9.83824825e+00, -1.19267998e+01, -4.40407753e+01, ...,
#            3.47875404e+01,  2.59345531e+01,  2.20770340e+01],
#          [-1.50527847e+00, -5.95605850e+00, -2.57029762e+01, ...,
#            2.47954712e+01,  2.08956490e+01,  1.33712749e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-1.56697170e-05, -7.37174150e-06, -3.70954672e-06, ...,
#           -8.26005362e-06, -1.19513506e-05, -7.69036524e-06],
#          ...,
#          [ 5.62006111e+01, -3.86459732e+00,  5.94868279e+01, ...,
#            4.60871048e+01,  6.48433228e+01,  2.80976849e+01],
#          [ 3.99731598e+01,  4.37755203e+00,  4.72795830e+01, ...,
#           -2.87843456e+01, -2.31445408e+01, -2.33153591e+01],
#          [ 1.06482840e+01, -4.90189171e+00,  7.81080856e+01, ...,
#           -6.53468323e+01, -7.84588089e+01, -2.35530777e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 5.39650159e-07, -6.04931074e-07, -1.47853427e-06, ...,
#           -1.51303493e-05, -1.58312268e-05, -1.74075631e-05],
#          ...,
#          [-1.88422298e+01,  2.29393244e-01, -1.41151142e+01, ...,
#           -2.58406487e+01,  6.72737455e+00,  8.47317410e+00],
#          [-1.01667433e+01, -7.07322121e+00,  4.93877373e+01, ...,
#            2.69492111e+01,  2.89871674e+01,  2.98779335e+01],
#          [-3.79535255e+01, -7.46747160e+00,  7.31663513e+01, ...,
#            2.94745979e+01,  3.74909363e+01,  3.05237350e+01]],
#
#         ...,
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-7.11439425e-05, -1.19240132e-04, -1.08924687e-04, ...,
#            7.99012105e-06,  1.02541426e-05,  1.13277601e-05],
#          ...,
#          [ 3.91887665e+01, -2.91308270e+01, -6.90127640e+01, ...,
#            8.93010426e+00,  2.27532406e+01, -3.51341400e+01],
#          [ 4.67350845e+01, -2.32332528e-01,  5.27046728e+00, ...,
#           -5.62840700e+00, -2.38351994e+01, -2.13890762e+01],
#          [ 6.27469711e+01, -5.42114449e+01,  3.59060822e+01, ...,
#           -2.34856319e+01, -3.41085510e+01, -2.03459568e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-7.71908890e-05, -9.48304223e-05, -9.38888188e-05, ...,
#            1.46405109e-05,  1.80538264e-05,  2.56325766e-05],
#          ...,
#          [ 1.69931107e+01, -2.73207817e+01,  1.82275124e+01, ...,
#            8.56876373e+00, -3.56880736e+00,  3.78155231e+00],
#          [ 1.58429594e+01, -8.24762344e-01, -6.17660027e+01, ...,
#            2.49157429e+01,  4.32553530e+00,  7.60069895e+00],
#          [ 6.83454056e+01, -5.80414295e+00, -1.25980339e+02, ...,
#            6.07206802e+01, -3.98602462e+00,  2.48111572e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-7.51726548e-05, -4.99376947e-05, -4.28890053e-05, ...,
#            2.06937075e-05,  1.87028400e-05,  2.31552694e-05],
#          ...,
#          [-9.42962945e-01, -7.05648804e+01, -6.28495483e+01, ...,
#           -7.92775269e+01, -2.80800867e+00, -8.59192848e+00],
#          [-2.61815701e+01, -1.08508272e+01,  4.31162491e+01, ...,
#           -2.54112778e+01, -4.93417702e+01, -1.43017082e+01],
#          [-2.65954437e+01,  3.87670517e+01,  1.36713593e+02, ...,
#            3.87453461e+01,  1.47621222e+01,  8.59242058e+00]]],
#
#
#        [[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-2.09886875e-05, -1.73429144e-05, -9.81619360e-06, ...,
#           -3.94676863e-05, -3.60165068e-05, -3.98374505e-05],
#          ...,
#          [ 9.90737152e+01,  6.76056442e+01, -5.48827019e+01, ...,
#            2.31973438e+01, -2.46381779e+01, -5.74829521e+01],
#          [ 6.39508209e+01, -4.36928062e+01, -4.00495386e+00, ...,
#            2.69501762e+01, -4.84949989e+01,  1.09035826e+01],
#          [ 1.18312578e+01, -7.23832550e+01,  5.86626930e+01, ...,
#           -1.29882555e+01, -8.41003036e+00, -1.68969078e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-2.15323853e-05, -2.83430909e-05, -3.38651880e-05, ...,
#           -1.71045103e-05, -2.52976442e-05, -2.75933508e-05],
#          ...,
#          [ 5.12884750e+01,  5.81837606e+00,  6.12992134e+01, ...,
#           -3.79870262e+01,  3.51539350e+00,  5.40794449e+01],
#          [ 4.97514229e+01,  9.33970642e+00,  7.20330276e+01, ...,
#           -1.32176638e+01,  3.74367523e+01,  4.13208313e+01],
#          [ 4.67351227e+01,  6.86912079e+01,  2.68042984e+01, ...,
#            5.03300209e+01,  5.45360985e+01,  2.34673047e+00]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-1.99244496e-05, -2.56646817e-05, -2.69544926e-05, ...,
#           -3.85165804e-05, -3.88394401e-05, -2.92042223e-05],
#          ...,
#          [-2.57636223e+01, -2.46938190e+01,  1.19441109e+01, ...,
#            5.34019470e+01,  5.01905251e+00, -4.83506012e+01],
#          [ 1.60406609e+01, -2.37296543e+01, -1.27210007e+01, ...,
#            2.06243191e+01, -3.05429688e+01, -6.11201143e+00],
#          [ 3.46126175e+01, -1.38546782e+01,  2.10450668e+01, ...,
#           -2.49558620e+01, -6.16546898e+01,  3.75410690e+01]],
#
#         ...,
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-8.26273754e-05, -7.17336661e-05, -9.64941864e-05, ...,
#           -4.19148746e-05, -3.85859385e-05, -2.86014547e-05],
#          ...,
#          [-1.54369230e+01, -2.17501480e+02,  1.72919426e+01, ...,
#            2.85205898e+01, -4.28842306e+00, -8.19132614e+01],
#          [-7.88626175e+01, -1.92179611e+02, -7.67432022e+01, ...,
#           -3.10358047e+00, -4.19443512e+00, -2.96978893e+01],
#          [-1.75984329e+02, -9.26602249e+01, -1.13976936e+01, ...,
#           -5.70668907e+01,  1.48975391e+01,  3.63895454e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-1.58541559e-04, -1.35741822e-04, -7.24778220e-05, ...,
#           -1.82067088e-05, -1.12412272e-05, -5.56381838e-06],
#          ...,
#          [-1.74327888e+01,  9.71801605e+01,  4.40722694e+01, ...,
#            3.64655685e+01,  1.97495496e+00,  1.77880669e+01],
#          [ 4.73689308e+01, -7.44254303e+01,  4.93149338e+01, ...,
#            9.65944481e+00,  1.31618938e+01,  2.45367126e+01],
#          [ 3.99357872e+01,  2.24047184e+01, -2.68487511e+01, ...,
#           -1.85209200e-01,  2.97223511e+01, -2.07018070e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-5.96717073e-05, -4.86291501e-05, -3.69783847e-05, ...,
#           -2.66324350e-05, -1.88344402e-05, -4.01600992e-05],
#          ...,
#          [ 4.10408821e+01,  7.22638321e+01, -9.48230667e+01, ...,
#           -1.48084869e+02, -5.90930061e+01,  1.59101229e+01],
#          [-5.26337509e+01,  1.31161514e+02, -2.19784279e+01, ...,
#           -1.11365646e+02,  1.37159181e+00,  4.75545616e+01],
#          [-6.02150154e+00, -2.73004589e+01,  8.07253876e+01, ...,
#           -7.68591022e+00,  4.42233467e+01,  7.15025024e+01]]],
#
#
#        [[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-2.35424250e-05, -2.51768979e-05, -2.99598560e-05, ...,
#           -2.20077982e-05, -2.75984585e-05, -2.34337349e-05],
#          ...,
#          [ 9.48944702e+01,  2.83589439e+01,  2.13141098e+01, ...,
#           -1.25040503e+01, -6.68694839e+01, -2.58261681e+01],
#          [ 4.11302567e+01,  7.03451633e+00,  1.82990360e+01, ...,
#           -8.94667149e+00,  5.83606386e+00,  8.39314365e+00],
#          [-9.07022953e+00,  1.74822826e+01, -8.14668846e+00, ...,
#            1.17438087e+01, -3.99192166e+00,  3.32450523e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-2.51644960e-05, -4.34031535e-05, -3.01096297e-05, ...,
#           -4.39216601e-05, -4.70842351e-05, -4.90212187e-05],
#          ...,
#          [-4.08608742e+01, -1.07027264e+01,  1.12501888e+01, ...,
#            2.63033466e+01, -7.58179245e+01,  5.00337563e+01],
#          [-1.59588442e+01,  3.97763901e+01,  2.30810719e+01, ...,
#            3.93356476e+01, -1.84870872e+01, -3.46997070e+00],
#          [-1.66036663e+01,  5.55330467e+01,  4.13266830e+01, ...,
#            6.75144196e+00, -8.72564411e+00, -3.50325928e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-2.43097911e-05, -2.20316178e-05, -2.86263912e-05, ...,
#           -4.18555137e-05, -3.72828908e-05, -3.66910572e-05],
#          ...,
#          [-2.88422985e+01, -1.13333122e+02,  4.51948853e+01, ...,
#           -5.81789742e+01, -1.52193708e+01, -6.56713247e+00],
#          [-7.35105820e+01, -7.31085663e+01,  8.47593307e+01, ...,
#           -3.99909630e+01,  8.47465134e+00, -5.78124084e+01],
#          [-1.11941566e+02, -4.53733902e+01,  1.18466064e+02, ...,
#           -2.66233616e+01,  6.42301254e+01,  5.57677422e+01]],
#
#         ...,
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-5.31690130e-05, -5.53606114e-05, -5.76788298e-05, ...,
#           -2.17013767e-05, -3.35628683e-05, -3.28470669e-05],
#          ...,
#          [-1.17214088e+02, -1.56609745e+01,  1.14258659e+02, ...,
#            2.75545444e+01, -6.29949226e+01,  4.62309122e-01],
#          [-5.85934410e+01,  6.73944321e+01,  7.90869446e+01, ...,
#           -1.00411081e+01, -3.48682022e+01,  5.07230492e+01],
#          [ 3.64061317e+01,  8.35607605e+01,  6.27615929e+01, ...,
#           -4.71304359e+01, -3.03624558e+00,  7.52641983e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-4.37847448e-05, -3.52091301e-05, -2.71302597e-05, ...,
#           -3.10835530e-05, -3.62145765e-05, -3.56576347e-05],
#          ...,
#          [-4.49075432e+01, -5.49194069e+01,  1.55514650e+01, ...,
#            6.54133987e+01, -4.78728523e+01,  2.61748085e+01],
#          [ 4.72261578e-01,  2.76311226e+01, -6.94592361e+01, ...,
#           -1.97857704e+01, -3.51026802e+01, -1.74096704e+00],
#          [ 6.71985006e+00,  1.93393002e+01, -2.07380219e+01, ...,
#           -1.13852615e+01, -4.97676811e+01, -1.03497677e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-3.35595978e-05, -3.50868613e-05, -3.42772873e-05, ...,
#           -2.32146085e-05, -2.87820912e-05, -2.17908018e-05],
#          ...,
#          [ 3.24374924e+01,  1.14226631e+02, -3.97970276e+01, ...,
#            3.55424995e+01, -3.33185806e+01, -1.20842873e+02],
#          [-3.10274172e+00,  5.25175972e+01, -6.73275299e+01, ...,
#            1.72234650e+01,  1.94751663e+01,  5.62341642e+00],
#          [ 7.25828123e+00, -1.02862152e+02, -8.80747757e+01, ...,
#           -1.23133078e+01, -1.34276879e+00,  3.98561592e+01]]],
#
#
#        ...,
#
#
#        [[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-2.10338349e-05, -1.83543470e-05, -2.53168164e-05, ...,
#           -2.42994192e-05, -2.62190406e-05, -2.80376480e-05],
#          ...,
#          [ 5.11001129e+01, -5.90559530e+00,  4.57521362e+01, ...,
#            8.92036080e-01,  1.04179306e+02, -2.71983681e+01],
#          [-1.07689581e+01, -2.45433712e+01,  3.75436449e+00, ...,
#            1.99065762e+01,  1.49576244e+01, -3.63452988e+01],
#          [-5.42466621e+01, -5.90736313e+01, -1.10337412e+00, ...,
#            4.31612892e+01, -2.99317284e+01, -2.52765827e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-1.66321170e-05, -1.77118091e-05, -1.33300719e-05, ...,
#           -4.95569402e-05, -3.95584393e-05, -4.91847277e-05],
#          ...,
#          [ 7.95979156e+01, -1.15057297e+01,  7.15447388e+01, ...,
#           -4.23020935e+00,  2.43719845e+01, -5.99984932e+01],
#          [ 4.19549294e+01, -4.11330299e+01, -2.29184074e+01, ...,
#            2.18082352e+01,  1.16798296e+01,  4.84834366e+01],
#          [-7.76511192e+00, -5.28278923e+01, -1.27750351e+02, ...,
#            6.61799850e+01,  3.67612457e+01,  5.32014771e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-2.41612042e-06, -1.05086883e-06,  1.87055704e-07, ...,
#           -4.73546752e-05, -4.21226032e-05, -5.35519830e-05],
#          ...,
#          [-1.47849792e+02,  1.05124367e+02, -7.29506073e+01, ...,
#            4.51807289e+01,  1.84871845e+01,  1.46232195e+01],
#          [ 7.63643932e+00,  4.39773636e+01, -1.08732857e+02, ...,
#            9.80387783e+00, -4.61578522e+01,  1.16054630e+01],
#          [ 3.76051521e+01,  1.90364876e+01, -1.34502655e+02, ...,
#           -1.20054817e+01, -7.81231689e+01, -5.64270706e+01]],
#
#         ...,
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-3.67091125e-05, -4.02710648e-05, -5.01020259e-05, ...,
#           -1.42090394e-05, -2.50047324e-05, -2.15228501e-05],
#          ...,
#          [ 4.82679176e+01,  9.85730743e+01, -3.71031227e+01, ...,
#            9.53669357e+01,  3.09599476e+01,  5.28559647e+01],
#          [ 5.02903709e+01, -4.59075050e+01, -3.04541664e+01, ...,
#           -2.07454071e+01,  3.02194920e+01,  4.39750366e+01],
#          [ 8.25655441e+01, -3.13793755e+01,  3.78729057e+01, ...,
#            5.37193031e+01, -7.16748657e+01,  4.80930233e+00]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-5.22570444e-05, -7.66188896e-05, -5.68698670e-05, ...,
#           -2.50179837e-05, -2.22015005e-05, -1.71145075e-05],
#          ...,
#          [ 4.36045933e+00,  9.04908676e+01,  8.58711395e+01, ...,
#            1.14255562e+02,  1.60543652e+01,  3.52017479e+01],
#          [ 1.02222776e+01,  9.30560989e+01,  5.53265800e+01, ...,
#            7.68653183e+01,  3.49635315e+01, -5.65909157e+01],
#          [ 5.26556473e+01,  3.04026394e+01,  5.82273369e+01, ...,
#           -2.34645042e+01,  1.50120173e+01, -1.03478909e+00]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-2.67669166e-05, -4.81726711e-05, -7.08034713e-05, ...,
#           -2.62921385e-05, -4.03154409e-05, -3.89838751e-05],
#          ...,
#          [ 1.47549934e+01,  1.29847555e+01,  4.11894341e+01, ...,
#            3.37402992e+01,  1.82418182e+02,  8.70562363e+00],
#          [ 6.84963379e+01,  2.36260586e+01,  5.99200554e+01, ...,
#            3.72189283e+00,  8.74382172e+01,  3.17054248e+00],
#          [ 5.00865402e+01,  1.11741089e+02,  6.15729942e+01, ...,
#            9.28919525e+01, -1.10333595e+02, -1.30841742e+01]]],
#
#
#        [[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-1.08207030e-06, -3.76630146e-06, -5.52545862e-06, ...,
#           -6.08060554e-06, -8.57637951e-06, -6.72449642e-06],
#          ...,
#          [ 1.37226892e+00, -4.36538429e+01,  2.08749695e+01, ...,
#           -1.03398651e+02, -5.84445610e+01,  8.54052887e+01],
#          [-8.36888199e+01, -4.09255180e+01,  6.17680588e+01, ...,
#           -2.89117928e+01, -6.51057053e+01, -1.08763971e+01],
#          [-2.99293957e+01, -4.57898102e+01,  1.06470207e+02, ...,
#           -4.10645752e+01,  2.97195206e+01, -1.45371597e+02]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 2.27816577e-06,  1.42190220e-06,  2.37992779e-07, ...,
#           -9.10337894e-06, -5.86663646e-06, -5.56653640e-06],
#          ...,
#          [-1.14629150e+02,  2.04194336e+02, -1.18645721e+02, ...,
#            3.34796524e+01, -3.27215614e+01,  4.69702873e+01],
#          [-3.24861183e+01,  6.55185547e+01, -9.03363647e+01, ...,
#           -3.25207734e+00,  7.81332314e-01,  2.74272938e+01],
#          [-1.35839432e+02, -8.90701828e+01,  4.40833473e+01, ...,
#           -1.32584591e+01,  1.96187401e+01, -8.01122665e+00]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 5.71397322e-06,  6.97558426e-06,  4.55473219e-06, ...,
#           -3.92280635e-05, -4.71319581e-05, -3.28399437e-05],
#          ...,
#          [ 5.76607704e+01,  2.79735699e+01, -7.63986969e+01, ...,
#            7.85347977e+01,  5.21216850e+01,  5.57887650e+01],
#          [ 3.83297119e+01,  7.54046011e+00, -3.22501526e+01, ...,
#            8.34273605e+01,  1.26569014e+01,  3.09543209e+01],
#          [ 6.07960052e+01,  3.58944249e+00, -7.76111679e+01, ...,
#            9.13980255e+01,  6.33279181e+00, -3.56436920e+01]],
#
#         ...,
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-1.43273119e-05, -1.64492885e-05, -2.21876671e-05, ...,
#           -1.44567475e-05, -1.21405410e-05, -6.55768963e-06],
#          ...,
#          [ 2.53862686e+01, -2.34991608e+01,  2.16868019e+01, ...,
#            5.54513817e+01, -1.28925109e+00,  2.62616367e+01],
#          [ 1.57709255e+01,  1.85467758e+01,  2.39682903e+01, ...,
#           -1.52581739e+01,  5.46406364e+01,  3.27130432e+01],
#          [ 8.76258659e+00,  4.08906631e+01,  1.71465778e+01, ...,
#            5.70345640e+00,  3.90961761e+01, -3.01119232e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-6.81644178e-06, -6.62358752e-06, -6.87108377e-06, ...,
#           -1.22976990e-05, -5.69924214e-06, -2.14072702e-06],
#          ...,
#          [-4.63076744e+01, -4.72541237e+00,  3.71870461e+01, ...,
#           -7.15071106e+01, -5.10031052e+01,  1.34286594e+01],
#          [ 5.39293289e+00, -1.83619385e+01,  6.90279312e+01, ...,
#           -2.08834553e+01, -4.52107658e+01, -9.45382977e+00],
#          [ 8.96018448e+01, -5.73192635e+01,  7.33404694e+01, ...,
#           -1.41924410e+01, -1.01275047e+02,  4.67643118e+00]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-8.61910030e-06, -1.37880115e-05, -9.94770198e-06, ...,
#           -8.97655718e-06, -3.91072990e-06,  3.36603478e-07],
#          ...,
#          [ 6.34877853e+01,  2.55847397e+01,  7.34039001e+01, ...,
#            3.96540184e+01,  3.39494133e+01,  5.06685400e+00],
#          [ 6.50611038e+01,  2.16287117e+01,  2.67424450e+01, ...,
#            3.96250610e+01,  7.31650467e+01,  7.95826578e+00],
#          [ 5.87611694e+01,  6.51841342e-01, -6.88299370e+00, ...,
#            3.48547440e+01,  5.12590637e+01,  2.14664459e+01]]],
#
#
#        [[[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-7.55709880e-06, -6.13184284e-06, -9.41751841e-06, ...,
#            8.63264813e-06,  9.83325481e-06,  1.02388894e-05],
#          ...,
#          [ 6.54538803e+01, -5.07753086e+00,  1.62956009e+01, ...,
#           -1.62964401e+01,  5.00662117e+01,  9.70903244e+01],
#          [ 6.67404022e+01,  3.18777752e+01,  1.19140596e+01, ...,
#            2.63970451e+01,  1.23298655e+01,  4.46372604e+01],
#          [ 4.98961792e+01,  5.30587234e+01,  3.53853455e+01, ...,
#            4.51861877e+01,  3.44662905e+00,  5.21655235e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 9.45035410e-08, -1.07901906e-06, -2.36474170e-06, ...,
#            6.74600142e-06,  6.58899944e-06,  8.60409182e-06],
#          ...,
#          [-8.90565681e+00, -4.35845528e+01,  7.27241135e+01, ...,
#           -5.29399338e+01, -3.24247780e+01,  3.89234467e+01],
#          [-1.49113989e+01,  1.84259777e+01,  5.92982559e+01, ...,
#            4.37778807e+00, -8.89491043e+01,  1.44635553e+01],
#          [-7.56799889e+00,  2.34836388e+01,  5.78591919e+01, ...,
#            5.45262222e+01, -4.28295746e+01, -9.51304531e+00]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 6.46023273e-06,  3.70702901e-06,  2.69200837e-06, ...,
#            8.18251283e-06,  1.23377495e-05,  7.50409072e-06],
#          ...,
#          [ 3.36361732e+01, -3.47459831e+01,  1.18922815e+01, ...,
#           -7.28113556e+01, -6.89578857e+01,  3.70702553e+01],
#          [ 5.50489426e+01, -2.57860680e+01, -3.54553452e+01, ...,
#           -2.52022476e+01, -5.64568863e+01,  5.23945427e+00],
#          [ 1.10254654e+02,  3.68618813e+01, -9.07667542e+01, ...,
#            6.02655907e+01,  6.77782822e+00,  4.78975868e+00]],
#
#         ...,
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-5.80203414e-06, -8.78777792e-06, -9.15483906e-06, ...,
#            4.20716651e-06,  3.31721162e-06,  4.37096242e-06],
#          ...,
#          [ 6.65199127e+01, -8.77104416e+01, -5.83381805e+01, ...,
#            5.51979408e+01,  8.89065247e+01, -2.85724850e+01],
#          [ 1.18153770e+02,  1.78756218e+01, -2.15646915e+01, ...,
#            3.58675423e+01,  7.62864380e+01,  1.15194511e+01],
#          [ 8.69411392e+01,  9.54277802e+01,  4.79933662e+01, ...,
#            8.60613823e+00,  3.64190521e+01,  2.73941307e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-1.26005125e-05, -1.88755876e-05, -1.54204663e-05, ...,
#            6.07623178e-06,  8.90734100e-06,  8.94998448e-06],
#          ...,
#          [ 6.69567823e+00,  9.59927826e+01,  5.41323662e+01, ...,
#            1.33283682e+01,  3.93393173e+01, -2.40944786e+01],
#          [ 2.16212330e+01,  1.95678196e+01,  6.00687485e+01, ...,
#           -1.34927683e+01,  7.69156570e+01,  6.82212524e+01],
#          [-3.16590190e+00, -3.90138893e+01,  8.15664291e+00, ...,
#           -5.93512459e+01,  8.35051422e+01,  7.77765961e+01]],
#
#         [[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#            0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#          [-1.27645681e-05, -1.67985145e-05, -2.35432271e-05, ...,
#            1.77018501e-05,  2.27461933e-05,  2.29993948e-05],
#          ...,
#          [ 7.35688782e+01,  9.78282318e+01,  2.15033588e+01, ...,
#            2.89570808e+01,  3.32159376e+00,  4.78021927e+01],
#          [ 7.70719070e+01,  4.83300514e+01, -1.11780481e+01, ...,
#            1.44459982e+01,  1.87936573e+01,  5.64065056e+01],
#          [ 1.25209251e+02,  2.24960213e+01, -3.22284164e+01, ...,
#           -1.35744064e+02,  4.30228920e+01,  8.79191666e+01]]]],
#       dtype=float32), 'TPHYSTND': array([[[[ 5.53345025e-01,  9.72958684e-01,  1.35975623e+00, ...,
#           -1.11870587e+00, -6.06568336e-01,  1.10296346e-01],
#          [ 1.32561302e+00,  1.82647276e+00,  2.26685190e+00, ...,
#           -1.57407427e+00, -5.71714818e-01,  6.71361387e-01],
#          [-6.13218832e+00, -8.07491207e+00,  2.63592696e+00, ...,
#           -6.42891645e+00, -7.18724787e-01, -2.52149439e+00],
#          ...,
#          [ 4.96747160e+00, -1.11585398e+01,  1.43722849e+01, ...,
#           -6.88172388e+00, -5.16529465e+00, -7.10663319e-01],
#          [ 4.45357609e+00, -8.41621208e+00,  1.68315125e+01, ...,
#           -2.63401866e+00, -1.57802105e+00, -4.48160738e-01],
#          [ 1.23357630e+00, -3.67452669e+00,  1.12465525e+01, ...,
#            2.13617027e-01,  3.82773399e-01, -1.95367947e-01]],
#
#         [[ 8.00717235e-01,  1.15215361e+00,  1.50799012e+00, ...,
#           -7.74497926e-01, -1.78602085e-01,  2.47049615e-01],
#          [ 1.66350150e+00,  2.02666879e+00,  2.41750717e+00, ...,
#           -8.58995914e-01,  2.49189287e-01,  8.81129205e-01],
#          [-7.42109203e+00, -2.80568647e+00,  2.41096115e+00, ...,
#           -1.99341011e+00, -3.08553720e+00,  2.38818312e+00],
#          ...,
#          [ 3.86074662e+00,  6.55975914e+00, -2.73238754e+00, ...,
#            4.75203800e+00, -4.07817268e+00, -1.59866726e+00],
#          [-8.55821991e+00,  8.40042019e+00,  1.50300283e+01, ...,
#            4.58814144e+00,  4.43467379e+00,  3.63333273e+00],
#          [-1.85621090e+01,  1.72761898e+01,  1.62991352e+01, ...,
#           -6.61770201e+00, -1.45602807e-01, -4.86982077e-01]],
#
#         [[ 9.89100814e-01,  1.38888347e+00,  1.67130280e+00, ...,
#           -7.02356160e-01, -2.38631833e-02,  3.86316538e-01],
#          [ 1.87628186e+00,  2.36408854e+00,  2.60455108e+00, ...,
#           -6.37409866e-01,  5.72556436e-01,  1.07094300e+00],
#          [-1.15805387e+00,  3.68775576e-01,  2.98414445e+00, ...,
#           -4.35324848e-01,  7.97163129e-01,  9.23406065e-01],
#          ...,
#          [ 1.37782850e+01,  1.62362061e+01,  3.17744136e+00, ...,
#           -3.96162160e-02, -7.18326187e+00, -4.63930655e+00],
#          [ 5.84529257e+00,  9.06506824e+00,  7.51072216e+00, ...,
#           -2.76621628e+00, -5.40497923e+00, -3.61151600e+00],
#          [ 4.03623581e+00,  8.85437489e+00,  5.44179296e+00, ...,
#            1.57338941e+00,  2.68601680e+00,  3.78098559e+00]],
#
#         ...,
#
#         [[ 5.32900132e-02,  4.76683974e-01,  8.77200484e-01, ...,
#           -1.04750466e+00, -1.05373335e+00, -5.67719400e-01],
#          [ 7.12868929e-01,  1.20537817e+00,  1.65732098e+00, ...,
#           -1.59564745e+00, -1.60557961e+00, -6.29808486e-01],
#          [-1.49644244e+00, -4.80199909e+00, -4.16509962e+00, ...,
#           -3.19677091e+00,  8.43669325e-02, -8.64372730e-01],
#          ...,
#          [-8.31421947e+00,  7.95602417e+00,  6.95383310e+00, ...,
#           -2.51322293e+00, -4.42946285e-01,  1.50651848e+00],
#          [-1.57128115e+01,  3.46747160e+00,  6.54415321e+00, ...,
#           -3.20114374e-01, -1.80940673e-01, -3.64495844e-01],
#          [-1.50330582e+01, -2.07343483e+00,  8.30609035e+00, ...,
#           -7.31294096e-01, -6.35081291e-01, -3.02487946e+00]],
#
#         [[ 2.38565862e-01,  6.38985872e-01,  1.03967381e+00, ...,
#           -1.06337583e+00, -7.49271929e-01, -1.85213685e-01],
#          [ 9.64957058e-01,  1.41062260e+00,  1.86999381e+00, ...,
#           -1.61471081e+00, -1.05683124e+00,  8.26499797e-03],
#          [-2.12954068e+00, -3.93477440e+00, -3.45228410e+00, ...,
#           -4.51761246e+00, -3.55178213e+00, -6.55831957e+00],
#          ...,
#          [-1.13162136e+00,  1.00874624e+01,  1.16491947e+01, ...,
#           -2.67107749e+00,  3.39659691e-01, -9.97523308e-01],
#          [ 3.46273971e+00,  3.83498287e+00,  6.12027693e+00, ...,
#           -2.73140121e+00, -3.24423528e+00, -1.89007056e+00],
#          [ 5.78859711e+00, -4.82745552e+00,  3.46758556e+00, ...,
#           -1.64324725e+00,  2.15112019e+00,  2.83956814e+00]],
#
#         [[ 3.81399035e-01,  7.98124611e-01,  1.21453571e+00, ...,
#           -1.09252548e+00, -6.58831060e-01, -7.13954121e-03],
#          [ 1.11831582e+00,  1.60693920e+00,  2.11094069e+00, ...,
#           -1.60449266e+00, -7.22229600e-01,  4.54477996e-01],
#          [-3.68436933e+00, -1.17171776e+00,  1.11195505e+00, ...,
#           -5.32815361e+00, -1.96240318e+00, -2.21468091e+00],
#          ...,
#          [ 2.15791488e+00,  9.83487606e+00, -1.63546925e+01, ...,
#            8.83087826e+00, -4.81219625e+00,  1.26765800e+00],
#          [ 5.87419176e+00,  7.03272438e+00, -2.63776855e+01, ...,
#            1.05325210e+00,  2.33333588e+00,  4.25838280e+00],
#          [ 1.41921778e+01,  7.22612190e+00, -2.35841179e+01, ...,
#            3.41635883e-01,  9.79800987e+00,  9.71440792e+00]]],
#
#
#        [[[ 5.78917801e-01,  9.58229661e-01,  1.33228147e+00, ...,
#           -1.14862180e+00, -6.61477149e-01,  5.57314493e-02],
#          [ 1.29293931e+00,  1.71665025e+00,  2.14420724e+00, ...,
#           -1.62004447e+00, -6.66118443e-01,  5.96332669e-01],
#          [-2.25073862e+00,  2.87975371e-03, -6.37802482e-01, ...,
#           -9.07644272e+00, -5.54628372e+00, -3.23250175e+00],
#          ...,
#          [-4.98958445e+00,  9.91553593e+00,  5.38435316e+00, ...,
#           -4.64405417e-01,  4.06782103e+00,  1.01671696e+00],
#          [ 4.24446630e+00,  1.14886742e+01,  5.75830173e+00, ...,
#            1.62781107e+00,  1.04480600e+01, -6.48280263e-01],
#          [ 2.86565948e+00,  1.32121239e+01,  1.19699478e+01, ...,
#            5.14784622e+00,  1.11321220e+01,  6.80944729e+00]],
#
#         [[ 7.51499534e-01,  1.09896886e+00,  1.45113027e+00, ...,
#           -9.19751823e-01, -3.49861562e-01,  1.59355417e-01],
#          [ 1.47994602e+00,  1.83627689e+00,  2.21057343e+00, ...,
#           -1.17213213e+00, -9.98538733e-02,  7.88008928e-01],
#          [-5.51225996e+00, -6.31119537e+00, -7.70522165e+00, ...,
#           -1.60701394e+00,  2.78870851e-01, -2.50747681e-01],
#          ...,
#          [ 1.13226786e+01, -4.67156023e-01,  1.00724173e+00, ...,
#           -4.48533863e-01, -5.60741329e+00, -6.68227673e+00],
#          [-2.83256507e+00,  1.97689190e+01,  1.17601814e+01, ...,
#            2.25259709e+00, -5.13350487e+00, -6.58034849e+00],
#          [ 9.31047440e+00,  1.90718098e+01,  1.50038300e+01, ...,
#            5.74424553e+00,  2.89402580e+00,  3.49578142e+00]],
#
#         [[ 9.08655524e-01,  1.30294132e+00,  1.66045165e+00, ...,
#           -7.80172527e-01, -1.09354377e-01,  3.33432049e-01],
#          [ 1.66139734e+00,  2.12156844e+00,  2.51086783e+00, ...,
#           -6.90059662e-01,  5.21244168e-01,  1.09222627e+00],
#          [-2.75668979e+00, -7.63380384e+00, -7.71657467e+00, ...,
#           -1.73284960e+00, -2.10941291e+00,  9.28653061e-01],
#          ...,
#          [ 1.37514153e+01,  2.01859016e+01,  3.72048640e+00, ...,
#           -1.26932898e+01,  1.56426743e-01,  1.18004141e+01],
#          [ 8.91319942e+00,  1.67393169e+01, -6.84183598e+00, ...,
#           -7.50915956e+00,  9.14005566e+00,  3.46999955e+00],
#          [ 1.24358320e+01,  1.29882116e+01, -4.94392920e+00, ...,
#           -2.74554443e+01,  9.75062084e+00, -1.61713505e+00]],
#
#         ...,
#
#         [[ 2.91714519e-02,  4.64939803e-01,  8.99029970e-01, ...,
#           -1.03143871e+00, -1.02927268e+00, -5.60905874e-01],
#          [ 6.28036082e-01,  1.16654992e+00,  1.71415055e+00, ...,
#           -1.61450040e+00, -1.62210333e+00, -6.86304152e-01],
#          [-2.75548553e+00,  1.64095855e+00,  3.61392021e-01, ...,
#           -9.92556381e+00, -7.84411764e+00, -9.32320404e+00],
#          ...,
#          [ 1.00875435e+01,  3.16172791e+01,  2.05415773e+00, ...,
#           -9.94361305e+00,  1.38367963e+00,  2.22762108e+01],
#          [ 6.65348864e+00,  1.83270969e+01,  8.32642078e+00, ...,
#            2.27366710e+00, -1.96935129e+00,  5.16604471e+00],
#          [ 8.51163030e-01,  1.00641670e+01,  1.12288418e+01, ...,
#            1.77435093e+01,  2.38663983e+00, -1.34154451e+00]],
#
#         [[ 2.25740746e-01,  6.61445618e-01,  1.01907849e+00, ...,
#           -1.07689893e+00, -1.07041657e+00, -5.24012983e-01],
#          [ 8.91280174e-01,  1.42246759e+00,  1.79944956e+00, ...,
#           -1.62298334e+00, -1.62486088e+00, -5.91456473e-01],
#          [-9.70059395e+00, -7.46285152e+00, -1.71557033e+00, ...,
#            1.73931748e-01, -2.04663016e-02, -1.52835608e-01],
#          ...,
#          [ 4.35519266e+00,  1.12956038e+01, -2.63475227e+00, ...,
#           -1.00355825e+01, -1.51225054e+00, -4.14085484e+00],
#          [ 4.05601025e+00,  1.61596775e+01,  7.61483192e+00, ...,
#            2.08041787e+00, -2.77421451e+00, -1.04719019e+00],
#          [ 1.01853704e+01,  4.54608440e+00,  1.53230639e+01, ...,
#            4.09860849e+00,  2.38866568e+00,  2.40120959e+00]],
#
#         [[ 4.17637318e-01,  8.56599450e-01,  1.22175574e+00, ...,
#           -1.11427355e+00, -7.02579498e-01, -6.33521825e-02],
#          [ 1.13192546e+00,  1.67678595e+00,  2.08245206e+00, ...,
#           -1.64325726e+00, -8.38931561e-01,  3.13793808e-01],
#          [-6.55216265e+00,  1.93066984e-01, -1.81774318e+00, ...,
#           -5.21609402e+00, -1.05130749e+01, -3.38131428e+00],
#          ...,
#          [ 2.25813723e+00,  2.80006313e+00,  1.08683910e+01, ...,
#            2.57668552e+01,  2.96445351e+01, -1.79970436e+01],
#          [ 3.25376105e+00, -7.17934799e+00,  7.03928947e+00, ...,
#            2.31571865e+01, -9.72373295e+00, -4.94870806e+00],
#          [-1.39316769e+01,  1.87310734e+01,  9.60383892e+00, ...,
#            8.54607487e+00, -5.45016146e+00, -8.86983424e-02]]],
#
#
#        [[[ 4.62236166e-01,  8.45427513e-01,  1.18161106e+00, ...,
#           -1.17819786e+00, -7.19031811e-01, -3.19073386e-02],
#          [ 1.25043845e+00,  1.68496311e+00,  2.03327751e+00, ...,
#           -1.65977442e+00, -7.45143354e-01,  4.69837844e-01],
#          [-2.45652452e-01, -2.53485131e+00, -8.88687515e+00, ...,
#           -1.58899689e+00,  3.54766876e-01,  1.72569394e+00],
#          ...,
#          [-1.00302207e+00,  4.21318722e+00,  3.04368997e+00, ...,
#           -3.57686734e+00, -3.62143695e-01, -1.33627582e+00],
#          [ 9.36937904e+00,  5.63980055e+00,  1.08497429e+01, ...,
#           -1.36145508e+00, -4.11497307e+00, -1.83006763e+01],
#          [ 9.09089947e+00,  1.09455280e+01,  1.41722469e+01, ...,
#            3.49581051e+00, -6.54653430e-01, -2.65115166e+01]],
#
#         [[ 6.58743143e-01,  1.04273546e+00,  1.36924565e+00, ...,
#           -1.20864117e+00, -6.56759262e-01,  1.34240538e-01],
#          [ 1.53379488e+00,  1.96582270e+00,  2.28848648e+00, ...,
#           -1.79624045e+00, -7.43175328e-01,  6.18095517e-01],
#          [-3.94467258e+00, -6.53018951e+00, -1.57124162e+00, ...,
#           -3.39003873e+00, -5.27865934e+00, -3.24164963e+00],
#          ...,
#          [ 1.35048275e+01, -2.05374527e+00,  9.06707859e+00, ...,
#           -1.12617807e+01,  5.89383304e-01, -3.82489753e+00],
#          [ 1.05903349e+01,  7.83049822e+00,  4.60228729e+00, ...,
#           -8.20367718e+00, -3.43486953e+00,  4.22875643e+00],
#          [ 1.46454048e+01,  1.47724123e+01,  2.28735614e+00, ...,
#           -2.07738951e-01, -1.88389034e+01,  1.65908074e+00]],
#
#         [[ 7.46271849e-01,  1.15560484e+00,  1.58525240e+00, ...,
#           -7.62097657e-01, -1.17326863e-01,  3.69731367e-01],
#          [ 1.58947527e+00,  2.07181025e+00,  2.61882329e+00, ...,
#           -9.31885839e-01,  2.36315653e-01,  9.41699803e-01],
#          [-1.74832344e+00,  6.33008629e-02, -3.69282365e-01, ...,
#           -3.18160295e+00, -1.29068732e+00,  6.40563548e-01],
#          ...,
#          [ 1.71485691e+01,  1.45628967e+01, -1.03366385e+01, ...,
#            1.28724537e+01,  9.22266865e+00,  5.29569674e+00],
#          [ 1.06270561e+01,  1.28922606e+01, -9.40422344e+00, ...,
#            7.18044233e+00,  1.87425470e+00,  1.20227613e+01],
#          [ 1.56978011e-01,  1.00207129e+01, -5.21205544e-01, ...,
#            8.91611099e+00, -4.70981181e-01,  8.23729420e+00]],
#
#         ...,
#
#         [[-6.04923479e-02,  4.01092410e-01,  8.22451055e-01, ...,
#           -1.07634282e+00, -1.06747103e+00, -6.32076919e-01],
#          [ 6.29296243e-01,  1.26385832e+00,  1.79156804e+00, ...,
#           -1.58061635e+00, -1.56934965e+00, -7.09074557e-01],
#          [-1.03181887e+00, -1.97463930e+00, -1.85705459e+00, ...,
#           -2.53873348e+00, -5.61710644e+00, -4.01612091e+00],
#          ...,
#          [ 7.60917246e-01,  4.09144783e+00, -9.19005585e+00, ...,
#            1.68365085e+00,  8.16317272e+00, -8.50457668e+00],
#          [ 3.96778727e+00,  1.07068193e+00, -4.48256063e+00, ...,
#            1.14431369e+00,  8.99107265e+00, -1.52111645e+01],
#          [ 3.41089249e+00, -3.29350424e+00, -1.21601200e+01, ...,
#            3.58302665e+00,  5.49004984e+00, -8.51692772e+00]],
#
#         [[ 1.28797501e-01,  5.78441441e-01,  1.00450945e+00, ...,
#           -1.16401887e+00, -1.15496480e+00, -6.28322959e-01],
#          [ 8.83422554e-01,  1.45519960e+00,  1.99834168e+00, ...,
#           -1.69360507e+00, -1.68816280e+00, -6.79464400e-01],
#          [-6.01486683e+00, -4.28599215e+00, -2.19291067e+00, ...,
#           -2.50109267e+00, -4.44060421e+00, -3.45551920e+00],
#          ...,
#          [ 1.63308697e+01,  5.30704403e+00,  3.43721533e+00, ...,
#           -2.09160542e+00,  8.89377689e+00, -2.82238007e+00],
#          [-1.28036082e+00,  1.50024498e+00,  1.89100399e+01, ...,
#            7.72712088e+00,  4.04705858e+00,  4.45308018e+00],
#          [ 6.53840017e+00,  7.09020758e+00, -5.80927467e+00, ...,
#           -4.66330576e+00,  2.31238055e+00,  1.05300674e+01]],
#
#         [[ 3.29715073e-01,  7.31701732e-01,  1.12831557e+00, ...,
#           -1.16857338e+00, -8.09765458e-01, -2.00598076e-01],
#          [ 1.12551928e+00,  1.60534084e+00,  2.08820486e+00, ...,
#           -1.63853824e+00, -9.93910432e-01,  1.26480028e-01],
#          [-1.91649926e+00,  1.35792643e-01, -3.39054608e+00, ...,
#           -1.66133702e+00, -1.50246775e+00,  4.38632637e-01],
#          ...,
#          [ 1.09656343e+01,  1.91061842e+00,  5.25268459e+00, ...,
#           -1.16696644e+00,  5.78283358e+00,  1.12888193e+01],
#          [ 2.91064095e+00,  6.23027802e+00,  1.65314255e+01, ...,
#            1.11581504e+00,  1.72972393e+00, -2.37793040e+00],
#          [-5.42355013e+00,  4.93857288e+00,  1.69084969e+01, ...,
#            2.10226345e+00,  3.34657359e+00,  2.74589610e+00]]],
#
#
#        ...,
#
#
#        [[[-4.34446745e-02,  3.86056185e-01,  7.69439757e-01, ...,
#           -9.89399493e-01, -9.84990358e-01, -6.57449484e-01],
#          [-7.94881508e-02,  5.38515508e-01,  9.75163639e-01, ...,
#           -1.79012024e+00, -1.80799448e+00, -1.27657032e+00],
#          [-2.29630923e+00, -7.51094162e-01, -2.78745723e+00, ...,
#           -3.64635491e+00, -5.03624201e+00, -7.87340975e+00],
#          ...,
#          [ 8.68762207e+00,  1.07495165e+01,  6.85008168e-01, ...,
#            6.15865767e-01,  2.70411038e+00,  5.12422037e+00],
#          [ 7.83307886e+00,  1.14038115e+01,  2.46557188e+00, ...,
#           -1.03466492e+01,  1.16663325e+00,  1.18432302e+01],
#          [ 3.54640818e+00,  9.68587685e+00,  4.74446392e+00, ...,
#           -1.44962482e+01, -1.58151484e+01,  5.73553133e+00]],
#
#         [[ 1.46601245e-01,  5.51555276e-01,  9.21433568e-01, ...,
#           -1.01781273e+00, -1.00623751e+00, -5.73998034e-01],
#          [ 2.49717832e-01,  7.09545672e-01,  1.11361313e+00, ...,
#           -1.79829323e+00, -1.80229390e+00, -1.03415465e+00],
#          [-2.79913831e+00, -4.16013098e+00,  7.99154997e-01, ...,
#           -8.24480152e+00, -7.27144861e+00, -6.78582430e+00],
#          ...,
#          [ 3.18098831e+00,  9.11671257e+00,  1.29602680e+01, ...,
#            4.40867996e+00,  7.86987591e+00,  2.93254986e+01],
#          [ 1.05328684e+01,  1.09918604e+01,  1.59512863e+01, ...,
#           -6.05939245e+00, -1.02381878e+01, -2.32825994e+00],
#          [ 6.63399315e+00,  2.98312044e+00,  1.00239134e+01, ...,
#           -1.11114607e+01, -2.55634556e+01, -1.57047911e+01]],
#
#         [[ 2.79757589e-01,  6.77782178e-01,  1.05914259e+00, ...,
#           -1.03260422e+00, -1.02431428e+00, -5.12352645e-01],
#          [ 4.43041354e-01,  8.74738693e-01,  1.29137945e+00, ...,
#           -1.69441104e+00, -1.70921052e+00, -8.44569266e-01],
#          [-2.54656076e+00, -3.95043993e+00,  1.00219238e+00, ...,
#           -6.71289730e+00, -5.11335993e+00, -2.36921716e+00],
#          ...,
#          [ 1.21814775e+01, -7.66607475e+00,  2.54381065e+01, ...,
#            8.77811909e+00,  8.47008324e+00, -6.23365068e+00],
#          [ 2.50170326e+00, -1.28631067e+01,  1.34680424e+01, ...,
#            9.66779709e+00,  1.36907549e+01, -5.78171778e+00],
#          [ 5.23930836e+00, -1.79310741e+01,  5.62901688e+00, ...,
#            1.14574203e+01,  1.27033997e+01, -3.10847163e+00]],
#
#         ...,
#
#         [[-7.60922730e-01, -2.32305035e-01,  3.69876266e-01, ...,
#           -1.02865815e+00, -1.01943517e+00, -1.00925791e+00],
#          [-1.59963477e+00, -6.92164958e-01,  3.37734938e-01, ...,
#           -1.67621386e+00, -1.67568183e+00, -1.67335165e+00],
#          [-5.92412996e+00, -2.78003812e+00, -4.38566113e+00, ...,
#           -2.78274059e+00, -4.39586592e+00, -6.21700907e+00],
#          ...,
#          [-2.42842746e+00,  1.17147076e+00,  8.36205578e+00, ...,
#           -9.60799217e+00,  3.33300257e+00, -4.35166597e+00],
#          [ 8.77552986e+00,  1.53972206e+01,  6.29024839e+00, ...,
#           -2.41007137e+00, -4.72891666e-02, -3.46157122e+00],
#          [ 2.03693562e+01,  1.93261166e+01,  1.15069895e+01, ...,
#           -4.16451836e+00, -2.02431226e+00,  8.59710121e+00]],
#
#         [[-5.40184498e-01,  7.45069534e-02,  5.23056030e-01, ...,
#           -1.02366126e+00, -1.01317167e+00, -1.01197267e+00],
#          [-1.03052032e+00, -1.15227150e-02,  5.70917606e-01, ...,
#           -1.70399618e+00, -1.69221735e+00, -1.70342195e+00],
#          [-6.41532755e+00, -1.07492809e+01, -8.79245341e-01, ...,
#           -9.07462311e+00, -1.52646804e+00, -4.69414949e+00],
#          ...,
#          [-3.99853063e+00, -4.18568420e+00, -1.08588753e+01, ...,
#           -1.04718962e+01,  1.15692749e+01,  4.56200838e+00],
#          [-7.41857004e+00,  1.06437922e+01,  9.19713402e+00, ...,
#            1.02632742e+01,  2.37817025e+00,  1.69715748e+01],
#          [ 7.85229492e+00,  1.33107605e+01,  1.51637087e+01, ...,
#            5.06624937e+00,  4.38892937e+00,  1.27676458e+01]],
#
#         [[-4.56444561e-01,  2.33281642e-01,  6.39759362e-01, ...,
#           -1.00238323e+00, -9.94724929e-01, -9.85795736e-01],
#          [-8.31629992e-01,  2.81759411e-01,  7.64434397e-01, ...,
#           -1.73181963e+00, -1.74093974e+00, -1.74399769e+00],
#          [-1.17782021e+00, -7.42893982e+00, -9.51811123e+00, ...,
#           -4.17020082e+00, -2.65998912e+00, -1.09191895e+01],
#          ...,
#          [-8.62744999e+00, -7.79176283e+00, -3.68656135e+00, ...,
#           -6.26526296e-01, -3.13929615e+01,  6.32993984e+00],
#          [-9.57309341e+00, -1.03918219e+01,  7.20021009e+00, ...,
#            1.16886244e+01, -5.47603941e+00,  1.17079248e+01],
#          [-1.45417957e+01, -2.76532483e+00,  4.62939692e+00, ...,
#           -5.19830370e+00,  2.36712742e+01,  2.28455124e+01]]],
#
#
#        [[[-4.47668016e-01,  2.80653298e-01,  6.74445450e-01, ...,
#           -9.57596242e-01, -9.57167625e-01, -9.62821245e-01],
#          [-7.46645629e-01,  3.73147368e-01,  8.24762583e-01, ...,
#           -1.75533414e+00, -1.74953604e+00, -1.75893962e+00],
#          [-2.29422951e+00, -3.26915193e+00, -4.75207090e+00, ...,
#           -2.96025187e-01, -2.88176775e+00, -6.34260464e+00],
#          ...,
#          [ 1.61217098e+01,  1.39365358e+01, -7.07275581e+00, ...,
#            1.43531199e+01,  1.70421124e+01, -3.33183432e+00],
#          [ 8.60189438e+00,  6.21496534e+00, -1.16456861e+01, ...,
#            3.30556035e+00, -2.56891370e+00,  1.84497395e+01],
# ...
#           -1.34523642e+00, -1.45948553e+00, -1.37169623e+00],
#          [ 5.58688927e+00,  6.17783165e+00,  6.76665497e+00, ...,
#           -5.63410711e+00, -5.93325758e+00, -7.77579498e+00]],
#
#         [[ 1.99827969e-01,  6.12532735e-01,  9.13323104e-01, ...,
#           -1.13645887e+00, -1.11336112e+00, -4.80968475e-01],
#          [ 3.89223874e-01,  1.04889393e+00,  1.31049001e+00, ...,
#           -1.55778766e+00, -1.53203607e+00, -5.89910984e-01],
#          [-8.95046890e-01,  1.91972822e-01,  8.22920859e-01, ...,
#           -1.86690378e+00, -2.03514194e+00, -7.39467144e-01],
#          ...,
#          [ 2.39236355e+00,  8.18631291e-01,  4.71771657e-02, ...,
#           -9.64456856e-01, -7.64613450e-02, -5.75229347e-01],
#          [ 4.07921267e+00,  2.33873010e+00,  5.52323484e+00, ...,
#            8.59792531e-03,  3.53228867e-01,  2.71897435e-01],
#          [ 3.49075603e+00,  4.61800051e+00,  6.43638325e+00, ...,
#            8.20952356e-02,  1.13059986e+00,  2.04147124e+00]],
#
#         [[ 3.45105350e-01,  7.37121403e-01,  1.03356779e+00, ...,
#           -6.88158751e-01, -6.65950894e-01,  1.18147135e-02],
#          [ 6.10253394e-01,  1.16747510e+00,  1.52251840e+00, ...,
#           -9.20209765e-01, -8.50912690e-01,  1.89018369e-01],
#          [ 3.46835375e-01,  8.26242864e-01,  1.52695203e+00, ...,
#           -1.11576056e+00, -1.30136895e+00,  2.32466936e-01],
#          ...,
#          [-1.30584741e+00, -1.02085662e+00,  5.82250059e-02, ...,
#            4.39059544e+00,  4.38661671e+00,  3.50324321e+00],
#          [-1.67774582e+00, -1.03793037e+00,  4.91197288e-01, ...,
#            3.68720055e-01,  2.54584908e+00,  2.45016432e+00],
#          [-3.47594917e-01,  7.08449125e-01,  2.02237082e+00, ...,
#           -3.74832988e+00, -4.23175454e-01,  5.64062119e-01]]],
#
#
#        ...,
#
#
#        [[[-3.02819371e-01,  2.07448781e-01,  8.41763377e-01, ...,
#           -8.95301223e-01, -9.38455224e-01, -8.47202301e-01],
#          [-5.07598519e-01,  2.01740146e-01,  1.12251186e+00, ...,
#           -1.57179570e+00, -1.60223627e+00, -1.47922540e+00],
#          [-5.78123033e-01,  3.27265233e-01,  1.82165623e+00, ...,
#           -4.02510452e+00, -4.41726971e+00, -4.14112759e+00],
#          ...,
#          [ 4.83599567e+00,  1.05620403e+01,  9.29753494e+00, ...,
#            4.09915733e+00,  3.91081786e+00,  7.98716831e+00],
#          [ 6.22418118e+00,  8.90034103e+00,  1.02880039e+01, ...,
#            5.37098455e+00,  2.88266349e+00,  9.05155373e+00],
#          [ 6.87960434e+00,  3.18226409e+00,  9.72280884e+00, ...,
#            1.26449146e+01,  4.60495472e+00,  1.05370340e+01]],
#
#         [[ 1.64473116e-01,  8.02039981e-01,  1.13061976e+00, ...,
#           -1.06599319e+00, -1.02215850e+00, -6.89215541e-01],
#          [ 1.10386729e-01,  1.02877164e+00,  1.52235234e+00, ...,
#           -1.63167763e+00, -1.58070660e+00, -1.10882521e+00],
#          [ 8.91290605e-03,  1.09846342e+00,  7.14953721e-01, ...,
#           -3.63583374e+00, -3.00050473e+00, -1.92829132e+00],
#          ...,
#          [ 7.53667545e+00,  9.01589775e+00,  7.99855471e+00, ...,
#           -3.26846778e-01,  1.48137331e+00,  5.13767910e+00],
#          [ 7.43018103e+00,  9.58317566e+00,  6.36987638e+00, ...,
#            1.96174574e+00,  4.05784655e+00,  6.44390631e+00],
#          [ 4.44323730e+00,  6.99255705e+00,  2.04815650e+00, ...,
#            5.46936703e+00,  4.29307842e+00,  5.83917189e+00]],
#
#         [[ 1.89746380e-01,  7.87966371e-01,  1.26307225e+00, ...,
#           -1.15412831e+00, -1.19624710e+00, -6.22590184e-01],
#          [ 3.06962550e-01,  9.55249548e-01,  1.57770133e+00, ...,
#           -1.57840037e+00, -1.68433261e+00, -8.43721986e-01],
#          [-1.43422151e+00, -1.20571709e+00, -2.97835350e-01, ...,
#           -1.57776141e+00, -1.76196074e+00, -1.15033865e+00],
#          ...,
#          [ 9.91849422e-01,  6.10939550e+00,  6.42460299e+00, ...,
#            4.62007427e+00,  3.07393074e-03, -2.51144218e+00],
#          [-1.95211244e+00,  5.89152384e+00,  5.77758789e+00, ...,
#            5.04590988e+00,  1.42330122e+00,  1.38643277e+00],
#          [-1.94655597e+00,  5.48357868e+00,  5.60459423e+00, ...,
#            5.10320330e+00,  4.81628132e+00,  5.90528011e+00]],
#
#         ...,
#
#         [[-7.93576837e-01, -3.81688476e-02,  3.57184350e-01, ...,
#           -4.69651341e-01, -4.38436508e-01, -9.26523566e-01],
#          [-1.21735239e+00, -1.56177640e-01,  4.73401368e-01, ...,
#           -1.06719446e+00, -1.00750637e+00, -1.51838374e+00],
#          [-3.86159801e+00, -2.63499475e+00, -1.73687601e+00, ...,
#           -2.88226461e+00, -3.48910284e+00, -4.80634832e+00],
#          ...,
#          [ 1.53884315e+00,  2.46049833e+00,  3.09383988e+00, ...,
#            1.38825274e+01,  1.51934528e+01,  8.92592049e+00],
#          [ 3.38654089e+00,  6.70416403e+00,  4.53885555e+00, ...,
#            1.25554066e+01,  1.44778805e+01,  2.87601638e+00],
#          [ 8.49944496e+00,  1.28679600e+01,  1.26063261e+01, ...,
#            9.25389194e+00,  1.41706562e+01, -1.80501008e+00]],
#
#         [[-5.42650819e-01,  6.38771057e-02,  4.29884970e-01, ...,
#           -6.28155351e-01, -7.79786229e-01, -7.69426823e-01],
#          [-7.70913839e-01,  1.60203397e-01,  6.30795896e-01, ...,
#           -1.16236353e+00, -1.36955738e+00, -1.40774083e+00],
#          [-2.59205294e+00, -1.08845425e+00, -9.18818533e-01, ...,
#           -2.87742186e+00, -3.59207201e+00, -3.28961992e+00],
#          ...,
#          [ 1.95714664e+00,  1.79490805e+00,  1.12815857e+00, ...,
#            9.29096222e+00,  7.17352057e+00,  1.03619623e+01],
#          [ 6.45602512e+00,  4.54534006e+00,  4.32833338e+00, ...,
#            1.09986124e+01,  6.29150438e+00,  1.10739870e+01],
#          [ 8.81240177e+00,  7.37642527e+00,  6.36249495e+00, ...,
#            1.37579002e+01,  7.67970371e+00,  1.15145044e+01]],
#
#         [[-2.93165803e-01,  4.50242370e-01,  8.29736114e-01, ...,
#           -6.74072266e-01, -6.53780580e-01, -6.58879042e-01],
#          [-4.20197487e-01,  7.07350314e-01,  1.26180887e+00, ...,
#           -1.42144489e+00, -1.36794424e+00, -1.32926774e+00],
#          [-1.69591069e+00, -4.97977078e-01,  5.23683190e-01, ...,
#           -3.27054524e+00, -2.78021002e+00, -2.74388075e+00],
#          ...,
#          [ 2.04670763e+00, -1.11485958e-01,  2.13417482e+00, ...,
#            1.18262482e+01,  9.96227169e+00,  1.00646610e+01],
#          [ 3.89895749e+00,  4.60428858e+00,  4.72040129e+00, ...,
#            9.61532879e+00,  1.12675295e+01,  1.20510550e+01],
#          [ 4.11399984e+00,  4.85482407e+00,  5.32329559e+00, ...,
#            5.28400898e+00,  1.20109396e+01,  1.36675968e+01]]],
#
#
#        [[[-4.49801087e-01,  1.58206820e-02,  7.26178169e-01, ...,
#           -7.40956187e-01, -8.29969645e-01, -7.30794191e-01],
#          [-6.82590246e-01,  4.17591333e-02,  1.04553545e+00, ...,
#           -1.22174954e+00, -1.34582090e+00, -1.30376649e+00],
#          [-2.41562319e+00, -9.39993680e-01,  4.94515032e-01, ...,
#           -3.02549648e+00, -3.97048569e+00, -3.36266518e+00],
#          ...,
#          [ 7.09345579e+00,  1.08105917e+01,  1.98815227e+00, ...,
#            5.90545464e+00,  8.18783379e+00,  1.14242630e+01],
#          [ 6.79306364e+00,  1.05057945e+01,  6.71326017e+00, ...,
#            4.42297745e+00,  6.08840656e+00,  1.00537510e+01],
#          [ 7.21369267e+00,  4.63349962e+00,  6.32954550e+00, ...,
#            5.43679714e+00,  3.91097116e+00,  9.05505943e+00]],
#
#         [[-2.00651526e-01,  1.56361878e-01,  9.36726391e-01, ...,
#           -8.62060428e-01, -8.18620682e-01, -6.10889912e-01],
#          [-2.33303428e-01,  2.74247169e-01,  1.25494766e+00, ...,
#           -1.42811894e+00, -1.38650489e+00, -1.08248234e+00],
#          [-1.16686034e+00, -4.73637640e-01,  1.40767789e+00, ...,
#           -2.89773417e+00, -2.37844157e+00, -1.71593022e+00],
#          ...,
#          [ 1.23242331e+00,  1.56030226e+01,  1.69507923e+01, ...,
#            1.09495716e+01,  1.14109316e+01,  1.33230782e+01],
#          [ 4.93153906e+00,  1.32114935e+01,  1.42997427e+01, ...,
#            1.07607660e+01,  1.06537828e+01,  1.13126087e+01],
#          [ 8.60197449e+00,  4.62099886e+00,  4.81145716e+00, ...,
#            6.15075874e+00,  5.71592474e+00,  3.98119879e+00]],
#
#         [[ 2.98044086e-02,  4.85618353e-01,  1.29205167e+00, ...,
#           -1.02488136e+00, -9.65175390e-01, -7.75280356e-01],
#          [-9.47836637e-02,  4.58977193e-01,  1.70075583e+00, ...,
#           -1.56445503e+00, -1.62493348e+00, -1.20872474e+00],
#          [-1.49936247e+00, -8.12067688e-01,  1.15734071e-01, ...,
#           -3.48937035e+00, -3.84400940e+00, -3.00956202e+00],
#          ...,
#          [ 6.00278568e+00,  1.44418774e+01,  1.62335072e+01, ...,
#            1.18112803e+00,  6.93239355e+00,  5.78345490e+00],
#          [ 8.88061047e+00,  1.15150871e+01,  1.43571424e+01, ...,
#            4.83201504e+00,  6.82276249e+00,  3.61137342e+00],
#          [ 9.14047337e+00,  7.93754005e+00,  1.09719725e+01, ...,
#            5.24084663e+00,  1.41341295e+01,  7.29483938e+00]],
#
#         ...,
#
#         [[-8.82990241e-01, -4.04465556e-01,  3.29344928e-01, ...,
#           -7.73303509e-01, -6.18273854e-01, -5.03589511e-01],
#          [-1.39856505e+00, -6.85440779e-01,  3.94008666e-01, ...,
#           -1.42845058e+00, -1.09363794e+00, -9.37030911e-01],
#          [-2.57959104e+00, -1.38377166e+00,  7.45843500e-02, ...,
#           -4.13755417e+00, -4.17100668e+00, -3.82799816e+00],
#          ...,
#          [ 5.90121031e+00,  5.28929424e+00,  1.98654056e+00, ...,
#            2.33276958e+01,  1.81048870e+01,  1.36118431e+01],
#          [ 5.67489815e+00,  6.37655401e+00,  4.78856707e+00, ...,
#            1.96574764e+01,  1.18106976e+01,  1.26097126e+01],
#          [ 4.59737921e+00,  4.50367069e+00,  5.49211788e+00, ...,
#            2.25375271e+01,  8.62593365e+00,  1.20854197e+01]],
#
#         [[-5.52505493e-01, -1.29102826e-01,  5.22591710e-01, ...,
#           -5.36511421e-01, -7.17572689e-01, -8.26423168e-01],
#          [-9.78337646e-01, -2.77856588e-01,  5.87314069e-01, ...,
#           -8.71784210e-01, -1.12264359e+00, -1.31893849e+00],
#          [-2.36868453e+00, -1.34940457e+00, -1.12658739e+00, ...,
#           -3.91278219e+00, -3.89134645e+00, -3.48386598e+00],
#          ...,
#          [ 3.37993383e+00,  3.79467726e+00,  2.69316339e+00, ...,
#            9.38565552e-01,  3.90521502e+00,  6.90296316e+00],
#          [ 6.94064713e+00,  3.96064472e+00,  6.03032589e+00, ...,
#           -5.59768260e-01, -1.29246458e-01,  7.80587816e+00],
#          [ 4.91708326e+00,  3.80898309e+00,  2.10526371e+00, ...,
#            4.07957554e+00, -2.01520419e+00,  9.63096809e+00]],
#
#         [[-5.57433367e-01,  4.91558313e-02,  8.21979344e-01, ...,
#           -6.26735210e-01, -8.38317871e-01, -8.27418089e-01],
#          [-8.73701930e-01, -1.33410096e-02,  1.12285995e+00, ...,
#           -1.15445113e+00, -1.42192984e+00, -1.35447931e+00],
#          [-1.96866274e+00, -1.30661058e+00, -8.43737721e-02, ...,
#           -3.10136509e+00, -3.15152168e+00, -3.22985244e+00],
#          ...,
#          [ 3.66240835e+00,  1.79627895e+00, -8.78038228e-01, ...,
#            8.08211708e+00,  8.36998653e+00,  7.75496817e+00],
#          [ 4.27972412e+00,  4.40825844e+00,  3.86807013e+00, ...,
#            1.21171722e+01,  1.27867270e+01,  8.33156395e+00],
#          [ 4.47319365e+00,  5.36878061e+00,  6.27686214e+00, ...,
#            9.40433693e+00,  1.33991842e+01,  8.22067261e+00]]],
#
#
#        [[[-3.91429543e-01,  5.13372421e-02,  7.31614470e-01, ...,
#           -9.53037500e-01, -1.02337766e+00, -7.24579334e-01],
#          [-4.46652889e-01,  1.63842559e-01,  1.17176962e+00, ...,
#           -1.54695773e+00, -1.64070988e+00, -1.19555449e+00],
#          [-1.67323208e+00, -1.27997446e+00,  2.08002776e-01, ...,
#           -4.73567724e+00, -4.87505960e+00, -3.77141595e+00],
#          ...,
#          [ 6.60897827e+00,  2.95163369e+00,  6.28639174e+00, ...,
#            1.59178038e+01,  1.19115391e+01,  4.51453590e+00],
#          [ 1.11234579e+01,  4.82747412e+00,  5.24278069e+00, ...,
#            8.99828148e+00,  1.23138952e+01,  8.46908665e+00],
#          [ 2.19211845e+01,  1.60171471e+01,  9.70140839e+00, ...,
#           -1.56717658e+00,  1.32062645e+01,  1.96102867e+01]],
#
#         [[-1.55496716e-01,  8.13404918e-02,  6.28926635e-01, ...,
#           -7.90806413e-01, -8.26167822e-01, -7.28494644e-01],
#          [-1.30671978e-01,  1.91464722e-01,  8.17714095e-01, ...,
#           -1.28876472e+00, -1.34193635e+00, -1.21906209e+00],
#          [-2.01185369e+00, -1.12978601e+00,  3.01330060e-01, ...,
#           -3.30089998e+00, -3.03251314e+00, -3.00696874e+00],
#          ...,
#          [-5.30606508e-01,  1.21577692e+00,  4.58478022e+00, ...,
#            8.20526218e+00,  1.03758659e+01,  1.29923315e+01],
#          [ 4.39110184e+00,  2.93918896e+00,  6.07165003e+00, ...,
#            1.06866598e+01,  1.30354919e+01,  1.50952816e+01],
#          [ 1.35519180e+01,  7.12068033e+00,  8.29480553e+00, ...,
#            1.09840565e+01,  1.48170576e+01,  1.49236355e+01]],
#
#         [[-3.54291439e-01,  3.27044964e-01,  8.84909153e-01, ...,
#           -8.25025558e-01, -8.65635872e-01, -5.05480051e-01],
#          [-4.61979151e-01,  4.72732961e-01,  1.15829313e+00, ...,
#           -1.35377908e+00, -1.54331470e+00, -9.92996693e-01],
#          [-3.14499402e+00, -1.10950899e+00, -5.48246443e-01, ...,
#           -4.46662521e+00, -4.03012037e+00, -3.07078719e+00],
#          ...,
#          [-4.00382090e+00,  1.26419532e+00,  7.11946917e+00, ...,
#            6.47345591e+00,  9.26320839e+00,  1.02075071e+01],
#          [-7.87998962e+00,  1.09565377e+00,  6.44331360e+00, ...,
#            5.46730185e+00,  6.88105059e+00,  7.02420187e+00],
#          [-3.73825955e+00,  5.68801594e+00,  6.33041477e+00, ...,
#            1.28942881e+01,  8.14554119e+00,  4.50845051e+00]],
#
#         ...,
#
#         [[-8.30136895e-01, -4.96390224e-01,  1.65173709e-01, ...,
#           -5.42981148e-01, -3.07799339e-01, -1.73548818e-01],
#          [-1.35264444e+00, -8.25673580e-01,  1.84936821e-01, ...,
#           -1.13664961e+00, -9.01898861e-01, -7.52190471e-01],
#          [-3.44271541e+00, -2.08209324e+00, -6.13418162e-01, ...,
#           -2.44347954e+00, -1.58260798e+00, -1.78269935e+00],
#          ...,
#          [ 4.23270464e+00,  1.66566670e-01,  9.91421342e-02, ...,
#            2.21825466e+01,  2.65752926e+01,  2.77080460e+01],
#          [ 3.89753461e+00,  2.28898883e+00,  2.29371309e+00, ...,
#            2.15479279e+01,  2.27465286e+01,  2.51430302e+01],
#          [ 9.27440739e+00,  7.19632578e+00,  5.97961760e+00, ...,
#            1.70262394e+01,  1.39499464e+01,  1.84298782e+01]],
#
#         [[-7.92215586e-01, -1.86802268e-01,  2.62983978e-01, ...,
#           -5.89033604e-01, -6.41713500e-01, -6.65728688e-01],
#          [-1.26054168e+00, -3.55345130e-01,  3.33064914e-01, ...,
#           -1.06209564e+00, -1.26258016e+00, -1.34386349e+00],
#          [-3.43993711e+00, -2.63028836e+00, -1.56520343e+00, ...,
#           -3.99240303e+00, -3.76239395e+00, -3.76357341e+00],
#          ...,
#          [-1.46927476e-01, -7.34580100e-01, -6.67098343e-01, ...,
#            1.81578236e+01,  2.29363041e+01,  2.43817635e+01],
#          [-1.04791522e+00,  2.46617866e+00,  3.96023321e+00, ...,
#            1.67178268e+01,  1.90575085e+01,  2.01073341e+01],
#          [ 2.19114423e+00,  4.39149475e+00,  5.19612169e+00, ...,
#            1.59603720e+01,  1.00120802e+01,  9.68677902e+00]],
#
#         [[-6.54582858e-01, -2.01396346e-01,  6.52254879e-01, ...,
#           -6.50109649e-01, -6.83082819e-01, -5.08315563e-01],
#          [-9.14222956e-01, -1.82932019e-01,  1.00178552e+00, ...,
#           -1.17467427e+00, -1.21555614e+00, -1.08743608e+00],
#          [-2.56293440e+00, -9.37343657e-01,  2.12152272e-01, ...,
#           -3.47957301e+00, -3.70969200e+00, -3.31568503e+00],
#          ...,
#          [ 3.28740668e+00,  1.16217160e+00,  2.06674147e+00, ...,
#            1.95793495e+01,  1.72689667e+01,  1.89582195e+01],
#          [ 4.07971001e+00,  1.40506423e+00,  5.23540449e+00, ...,
#            1.80142879e+01,  1.63117123e+01,  1.87308216e+01],
#          [ 2.68758273e+00,  1.55849981e+00,  4.96162081e+00, ...,
#            1.39602985e+01,  1.62730465e+01,  1.58891478e+01]]]],
#       dtype=float32)}}}

# %%
# Load coordinates (just pick any file from the climate model run)
coor = xr.open_dataset("/scratch/05823/tg851228/CBRAIN/sp8fbp_minus4k/sp8fbp_minus4k.cam2.h1.0000-01-01-00000.nc",\
                    decode_times=False)
lat = coor.lat; lon = coor.lon; lev = coor.lev;
coor.close();

# %%
coor.lat[26:40] # A tropical latitude range that we can use for testing
# Out:
# <xarray.DataArray 'lat' (lat: 14)>
# array([-15.348365, -12.557756,  -9.767146,  -6.976534,  -4.185921,  -1.395307,
#          1.395307,   4.185921,   6.976534,   9.767146,  12.557756,  15.348365,
#         18.138971,  20.929574])
# Coordinates:
#   * lat      (lat) float64 -15.35 -12.56 -9.767 -6.977 ... 15.35 18.14 20.93
# Attributes:
#     long_name:  latitude
#     units:      degrees_north

# %%
coor.lat[13:20] # A mid-latitude range that we can use for testing
# Out:
# <xarray.DataArray 'lat' (lat: 7)>
# array([-51.625734, -48.835241, -46.044727, -43.254195, -40.463648, -37.67309 ,
#        -34.882521])
# Coordinates:
#   * lat      (lat) float64 -51.63 -48.84 -46.04 -43.25 -40.46 -37.67 -34.88
# Attributes:
#     long_name:  latitude
#     units:      degrees_north

# %%
coor.lat[0:7] # A polar range that we can use for testing
# Out:
# <xarray.DataArray 'lat' (lat: 7)>
# array([-87.863799, -85.096527, -82.312913, -79.525607, -76.7369  , -73.947515,
#        -71.157752])
# Coordinates:
#   * lat      (lat) float64 -87.86 -85.1 -82.31 -79.53 -76.74 -73.95 -71.16
# Attributes:
#     long_name:  latitude
#     units:      degrees_north

# %%
# Plot characteristics
fz = 20
lw = 4
plt.rc('text', usetex=True)
plt.rc('font',size=fz)
#plt.rc('font',**{'family':'serif','serif':['Computer Modern Roman']}, size=fz)
mpl.rcParams['lines.linewidth'] = lw
plt.close('all')

# %%
diagno['truth'].keys()
# Out:
# dict_keys(['M4K_valid', 'P4K_valid'])

# %% [markdown]
# Validation on the (-4K) dataset: Both network perform relatively well

# %%
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)
os.environ['PATH'] = os.environ['PATH'] + ':/home1/apps/texlive/2017/bin/x86_64-linux/latex'
# %matplotlib inline

# %%
data = 'M4K_valid'

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.axvline(x=0,c='lightgray')
for iNN,NNs in enumerate(NNarray[0:2]):
    plt.plot(np.mean(diagno[NNs][data]['PHQ'],axis=(0,1,3)),lev,label=NNname[iNN])
plt.plot(np.mean(diagno['truth'][data]['PHQ'],axis=(0,1,3)),lev,label='Truth',color='k')
plt.legend()
plt.xlabel('Convective moistening ($\mathrm{W\ m^{-2}}$)')
plt.ylabel('Pressure (hPa)')
plt.gca().invert_yaxis()
#plt.xlim((-20,20))

plt.subplot(1,2,2)
plt.axvline(x=0,c='lightgray')
for iNN,NNs in enumerate(NNarray[0:2]):
    plt.plot(np.mean(diagno[NNs][data]['TPHYSTND'],axis=(0,1,3)),lev,label=NNname[iNN])
plt.plot(np.mean(diagno['truth'][data]['TPHYSTND'],axis=(0,1,3)),lev,label='Truth',color='k')
plt.legend()
plt.xlabel('Convective heating ($\mathrm{W\ m^{-2}}$)')
plt.gca().invert_yaxis()
plt.xlim((-9,9))
# Out:
# (-9, 9)
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# On (+4K), the brute force is terrible and the RH is already an improvement

# %%
data = 'P4K_valid'

plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.axvline(x=0,c='lightgray')
for iNN,NNs in enumerate(NNarray[0:2]):
    plt.plot(np.mean(diagno[NNs][data]['PHQ'],axis=(0,1,3)),lev,label=NNname[iNN])
plt.plot(np.mean(diagno['truth'][data]['PHQ'],axis=(0,1,3)),lev,label='Truth',color='k')
plt.legend()
plt.xlabel('Convective moistening ($\mathrm{W\ m^{-2}}$)')
plt.ylabel('Pressure (hPa)')
plt.gca().invert_yaxis()
#plt.xlim((-20,20))

plt.subplot(1,2,2)
plt.axvline(x=0,c='lightgray')
for iNN,NNs in enumerate(NNarray[0:2]):
    plt.plot(np.mean(diagno[NNs][data]['TPHYSTND'],axis=(0,1,3)),lev,label=NNname[iNN])
plt.plot(np.mean(diagno['truth'][data]['TPHYSTND'],axis=(0,1,3)),lev,label='Truth',color='k')
plt.legend()
plt.xlabel('Convective heating ($\mathrm{W\ m^{-2}}$)')
plt.gca().invert_yaxis()
#plt.xlim((-9,9))
